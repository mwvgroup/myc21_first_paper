# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import optuna

from sklearn.model_selection import train_test_split, KFold
from sklearn.model_selection import cross_val_predict
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
import optuna.visualization as vis

import os

from astropy.cosmology import FlatLambdaCDM

# %%
df = pd.read_csv("data/ZTF_DESI_matched_lc_cuts_z_cuts_hostprop_cleaned_tripp_uncorrected_chi2_only.csv")

print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 513 entries, 0 to 512
# Data columns (total 69 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   ZTF_Unnamed: 0                    513 non-null    float64
#  1   ztfname                           513 non-null    object
#  2   ZTF_redshift                      513 non-null    float64
#  3   ZTF_redshift_err                  513 non-null    float64
#  4   ZTF_source                        513 non-null    object
#  5   ZTF_t0                            513 non-null    float64
#  6   ZTF_x0                            513 non-null    float64
#  7   ZTF_x1                            513 non-null    float64
#  8   ZTF_c                             513 non-null    float64
#  9   ZTF_t0_err                        513 non-null    float64
#  10  ZTF_x0_err                        513 non-null    float64
#  11  ZTF_x1_err                        513 non-null    float64
#  12  ZTF_c_err                         513 non-null    float64
#  13  ZTF_cov_t0_x0                     513 non-null    float64
#  14  ZTF_cov_t0_x1                     513 non-null    float64
#  15  ZTF_cov_t0_c                      513 non-null    float64
#  16  ZTF_cov_x0_x1                     513 non-null    float64
#  17  ZTF_cov_x0_c                      513 non-null    float64
#  18  ZTF_cov_x1_c                      513 non-null    float64
#  19  ZTF_mwebv                         513 non-null    float64
#  20  ZTF_mwr_v                         513 non-null    float64
#  21  ZTF_mwebv_err                     513 non-null    float64
#  22  ZTF_fitprob                       513 non-null    float64
#  23  ZTF_ra                            513 non-null    float64
#  24  ZTF_dec                           513 non-null    float64
#  25  ZTF_sn_type                       513 non-null    object
#  26  ZTF_sub_type                      431 non-null    object
#  27  ZTF_lccoverage_flag               513 non-null    float64
#  28  ZTF_fitquality_flag               513 non-null    float64
#  29  ZTF_iau_name                      499 non-null    object
#  30  ZTF_frac_fitted                   513 non-null    float64
#  31  ZTF_ra_host_global                513 non-null    float64
#  32  ZTF_dec_host_global               513 non-null    float64
#  33  ZTF_mass_global                   511 non-null    float64
#  34  ZTF_mass_err_global               511 non-null    float64
#  35  ZTF_restframe_gz_global           511 non-null    float64
#  36  ZTF_restframe_gz_err_global       511 non-null    float64
#  37  ZTF_d_dlr_global                  513 non-null    float64
#  38  ZTF_mass_local                    507 non-null    float64
#  39  ZTF_mass_err_local                511 non-null    float64
#  40  ZTF_restframe_gz_local            507 non-null    float64
#  41  ZTF_restframe_gz_err_local        507 non-null    float64
#  42  ZTF_DESI_METADATA_ang_sep_arcsec  513 non-null    float64
#  43  DESI_METADATA_TARGETID            513 non-null    float64
#  44  DESI_METADATA_LS_ID               513 non-null    float64
#  45  DESI_METADATA_SPECTYPE            513 non-null    object
#  46  DESI_METADATA_RA                  513 non-null    float64
#  47  DESI_METADATA_DEC                 513 non-null    float64
#  48  DESI_METADATA_DESI_TARGET         513 non-null    float64
#  49  DESI_METADATA_Z                   513 non-null    float64
#  50  DESI_METADATA_ZWARN               513 non-null    float64
#  51  DESI_METADATA_PROGRAM             513 non-null    object
#  52  DESI_METADATA_SURVEY              513 non-null    object
#  53  DESI_FASTSPEC_TARGETID            513 non-null    float64
#  54  DESI_FASTSPEC_HEALPIX             513 non-null    float64
#  55  DESI_FASTSPEC_VDISP               513 non-null    float64
#  56  DESI_FASTSPEC_VDISP_IVAR          513 non-null    float64
#  57  DESI_FASTSPEC_LOGMSTAR            513 non-null    float64
#  58  DESI_FASTSPEC_SFR                 513 non-null    float64
#  59  DESI_FASTSPEC_AGE                 513 non-null    float64
#  60  DESI_FASTSPEC_DN4000              513 non-null    float64
#  61  DESI_FASTSPEC_DN4000_IVAR         513 non-null    float64
#  62  DESI_FASTSPEC_ABSMAG01_SDSS_G     513 non-null    float64
#  63  DESI_FASTSPEC_ZZSUN               513 non-null    float64
#  64  DESI_FASTSPEC_ABSMAG01_SDSS_R     513 non-null    float64
#  65  DESI_FASTSPEC_g_minus_r           513 non-null    float64
#  66  ZTF_mu_obs                        513 non-null    float64
#  67  ZTF_sigma_mu                      513 non-null    float64
#  68  residuals                         513 non-null    float64
# dtypes: float64(61), object(8)
# memory usage: 276.7+ KB
# None

# %%
feature_cols = [
    "DESI_FASTSPEC_LOGMSTAR",
    "DESI_FASTSPEC_SFR",
    "DESI_FASTSPEC_VDISP",
    "DESI_FASTSPEC_DN4000",
    "DESI_FASTSPEC_g_minus_r",
    "DESI_FASTSPEC_AGE",
    "DESI_METADATA_Z",
    "ZTF_c",
    "ZTF_x1",
]

target_col = "residuals"

yerr_all = df["ZTF_sigma_mu"]

X = df[feature_cols]
y = df[target_col]

# %%
# No train/test split — we use 5-fold CV on the full dataset
X_np = X.to_numpy()
y_np = y.to_numpy()

# %% [markdown]
# # Defining Optuna Study Objective #
#
# Here we have to set a "reasonable" range of hyperparameters to tune for the random forest. This is b/c optuna doesn't just start from scratch.
#
#
# The full list of Random Forest Hyperparameters can be found here: https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestClassifier.html
#
# The parameters I choose to vary:
#
# n_estimatorsint, default=100 The number of trees in the forest. varying from defualt to 1500 in steps of 100.
# max_depthint, default=None The maximum depth of the tree. If None, then nodes are expanded until all leaves are pure or until all leaves contain less than min_samples_split samples. Ended up varying depth to some max amount. Did some trial and error to see what range is good. If the search settled on some smaller number, inceased to larger number and then dialed back so as not to waste computation space.
#
# min_samples_splitint or float, default=2 The minimum number of samples required to split an internal node: If int, then consider min_samples_split as the minimum number. If float, then min_samples_split is a fraction and ceil(min_samples_split * n_samples) are the minimum number of samples for each split. Started at the default and incrased to a larger number.
#
# min_samples_leafint or float, default=1
# The minimum number of samples required to be at a leaf node. A split point at any depth will only be considered if it leaves at least min_samples_leaf training samples in each of the left and right branches. This may have the effect of smoothing the model, especially in regression.
#
# If int, then consider min_samples_leaf as the minimum number. If float, then min_samples_leaf is a fraction and ceil(min_samples_leaf * n_samples) are the minimum number of samples for each node.
#
# ## `min_samples_leaf` — Controlling Leaf Bucket Size
#
# `min_samples_leaf` sets the minimum number of SNe Ia allowed in any
# final leaf node (bucket) of a decision tree.
#
# - `min_samples_leaf=1`: A leaf can contain a single SN. That SN's
#   Δμ becomes the prediction for anything landing in that bucket.
#   This is essentially memorizing individual data points.
#
# - `min_samples_leaf=10`: Every leaf must contain at least 10 SNe.
#   The prediction is the average Δμ of those 10 SNe — a much
#   smoother, more stable estimate that is harder to overfit.
#
# Our Optuna search explores the range 1–10, letting the optimization
# decide how granular the leaf buckets should be.
#
# ### Interaction with `max_depth`
#
# These two hyperparameters control the same thing — tree complexity —
# from opposite directions:
#
# - `max_depth` limits complexity **from the top**: how many sequential
#   splits a tree is allowed to make.
# - `min_samples_leaf` limits complexity **from the bottom**: how small
#   the resulting buckets can get.
#
# With our best-fit `max_depth=3` (~8 leaf nodes for 521 SNe), even
# `min_samples_leaf=1` is not dangerous because the tree is too shallow
# to isolate individual SNe. However, if Optuna had selected
# `max_depth=30`, then `min_samples_leaf` would serve as the safety
# net preventing the tree from creating tiny, noise-dominated buckets.
#
#
# # Max Features #
#
# "max_features": trial.suggest_categorical("max_features", ["sqrt", "log2", None]). Wnate dto play around what is better.
#
#
#
# The parameters I choose to keep default:
#
# criterion{“gini”, “entropy”, “log_loss”}, default=”gini”- b/c its the default method of criterion evaluation (See. 8.1.2 of "An Introductin to Statistical Learning")

# %%
def objective(trial):

    # Parameters we suggest to optimize and caps on their ranges.
    # Optuna will automatically sample values for these parameters within the specified ranges.
    # It will prune unpromising trials based on intermediate results. So not everything 
    params = {
        "n_estimators": trial.suggest_int("n_estimators", 100, 1500, step=100),
        "max_depth": trial.suggest_int("max_depth", 3, 30),
        "min_samples_split": trial.suggest_int("min_samples_split", 2, 20),
        "min_samples_leaf": trial.suggest_int("min_samples_leaf", 1, 20),
        "max_features": trial.suggest_categorical("max_features", ["sqrt", "log2", None]),
        "bootstrap": trial.suggest_categorical("bootstrap", [True, False]),
        "n_jobs": -1,
        "random_state": 42,
    }

    # only runs the following code if boostram is set to True.
    if params["bootstrap"]:
        params["max_samples"] = trial.suggest_float("max_samples", 0.5, 1.0)

    ## ** is python dictionary unpacking syntax
    # which allows us to pass the parameters as keyword arguments to the RandomForestRegressor constructor.
    rf = RandomForestRegressor(**params)

    # Creates a splitter object that will divide training data into 5 equal chunks. 
    # Shuffle True means that the data will be randomly shuffled before splitting
    # (ensures that each fold is representative of the overall dataset.). 
    kf = KFold(n_splits=5, shuffle=True, random_state=42)
    fold_scores = [] # for MSE scores of each fold

    # We had previously split the data into train/test (521/104)
    # 5-fold cross validation on the full 521 SNe.
    # Each fold: ~417 train and ~104 validation.
    for train_idx, val_idx in kf.split(X_np):
        X_fold_tr = X_np[train_idx]
        X_fold_val = X_np[val_idx]

        y_fold_tr = y_np[train_idx]
        y_fold_val = y_np[val_idx]

        rf.fit(X_fold_tr, y_fold_tr)
        y_fold_pred = rf.predict(X_fold_val)

        score = mean_squared_error(y_fold_val, y_fold_pred)
        fold_scores.append(score)

    # The Value Optuna is Minnimizing.
    return np.mean(fold_scores)

# %%
study_name = "optuna_runs_info/rf_prediction_uncorrected_tripp_host_chi2_only"

db_path = f"{study_name}.db"
if os.path.exists(db_path):
    os.remove(db_path)

study = optuna.create_study(direction="minimize", storage=f"sqlite:///{db_path}", study_name=study_name)
study.optimize(objective, n_trials=50, show_progress_bar=True) # 100 different hyperparameter combinations will be tried.

print("Best trial:", study.best_trial.number)
print("Best MSE:", study.best_value)
print("Best hyperparameters:")
print(study.best_params)
# Out:
# [I 2026-04-20 21:25:23,467] A new study created in RDB with name: optuna_runs_info/rf_prediction_uncorrected_tripp_host_chi2_only
#   0%|          | 0/50 [00:00<?, ?it/s]
# [I 2026-04-20 21:25:23,769] Trial 0 finished with value: 0.047006780527698674 and parameters: {'n_estimators': 100, 'max_depth': 10, 'min_samples_split': 14, 'min_samples_leaf': 14, 'max_features': 'sqrt', 'bootstrap': False}. Best is trial 0 with value: 0.047006780527698674.
# [I 2026-04-20 21:25:25,837] Trial 1 finished with value: 0.051683161799819785 and parameters: {'n_estimators': 1100, 'max_depth': 22, 'min_samples_split': 12, 'min_samples_leaf': 17, 'max_features': 'sqrt', 'bootstrap': True, 'max_samples': 0.9317949436856197}. Best is trial 0 with value: 0.047006780527698674.
# [I 2026-04-20 21:25:26,680] Trial 2 finished with value: 0.03701402422529276 and parameters: {'n_estimators': 400, 'max_depth': 10, 'min_samples_split': 8, 'min_samples_leaf': 7, 'max_features': None, 'bootstrap': True, 'max_samples': 0.6875955023875651}. Best is trial 2 with value: 0.03701402422529276.
# [I 2026-04-20 21:25:28,317] Trial 3 finished with value: 0.04510118246707016 and parameters: {'n_estimators': 1300, 'max_depth': 25, 'min_samples_split': 20, 'min_samples_leaf': 7, 'max_features': 'sqrt', 'bootstrap': False}. Best is trial 2 with value: 0.03701402422529276.
# [I 2026-04-20 21:25:28,675] Trial 4 finished with value: 0.04868324334726441 and parameters: {'n_estimators': 200, 'max_depth': 6, 'min_samples_split': 2, 'min_samples_leaf': 15, 'max_features': 'sqrt', 'bootstrap': False}. Best is trial 2 with value: 0.03701402422529276.
# [I 2026-04-20 21:25:31,288] Trial 5 finished with value: 0.03741052661482757 and parameters: {'n_estimators': 1400, 'max_depth': 5, 'min_samples_split': 7, 'min_samples_leaf': 2, 'max_features': None, 'bootstrap': True, 'max_samples': 0.9478391937743205}. Best is trial 2 with value: 0.03701402422529276.
# [I 2026-04-20 21:25:31,637] Trial 6 finished with value: 0.04949401680129675 and parameters: {'n_estimators': 200, 'max_depth': 5, 'min_samples_split': 7, 'min_samples_leaf': 14, 'max_features': 'sqrt', 'bootstrap': False}. Best is trial 2 with value: 0.03701402422529276.
# [I 2026-04-20 21:25:34,116] Trial 7 finished with value: 0.03733878886126489 and parameters: {'n_estimators': 1300, 'max_depth': 24, 'min_samples_split': 19, 'min_samples_leaf': 6, 'max_features': None, 'bootstrap': True, 'max_samples': 0.6865196259597577}. Best is trial 2 with value: 0.03701402422529276.
# [I 2026-04-20 21:25:34,942] Trial 8 finished with value: 0.05206644480602213 and parameters: {'n_estimators': 600, 'max_depth': 4, 'min_samples_split': 7, 'min_samples_leaf': 12, 'max_features': 'sqrt', 'bootstrap': False}. Best is trial 2 with value: 0.03701402422529276.
# [I 2026-04-20 21:25:35,820] Trial 9 finished with value: 0.0521473910232846 and parameters: {'n_estimators': 700, 'max_depth': 4, 'min_samples_split': 18, 'min_samples_leaf': 14, 'max_features': 'log2', 'bootstrap': False}. Best is trial 2 with value: 0.03701402422529276.
# [I 2026-04-20 21:25:36,876] Trial 10 finished with value: 0.038261067801003634 and parameters: {'n_estimators': 500, 'max_depth': 14, 'min_samples_split': 2, 'min_samples_leaf': 8, 'max_features': None, 'bootstrap': True, 'max_samples': 0.5005386650741462}. Best is trial 2 with value: 0.03701402422529276.
# [I 2026-04-20 21:25:38,838] Trial 11 finished with value: 0.03706081563161676 and parameters: {'n_estimators': 1000, 'max_depth': 29, 'min_samples_split': 17, 'min_samples_leaf': 2, 'max_features': None, 'bootstrap': True, 'max_samples': 0.6798120448446554}. Best is trial 2 with value: 0.03701402422529276.
# [I 2026-04-20 21:25:40,808] Trial 12 finished with value: 0.037324695246801605 and parameters: {'n_estimators': 1000, 'max_depth': 30, 'min_samples_split': 15, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': True, 'max_samples': 0.6649067640951595}. Best is trial 2 with value: 0.03701402422529276.
# [I 2026-04-20 21:25:42,585] Trial 13 finished with value: 0.03643386996991649 and parameters: {'n_estimators': 900, 'max_depth': 17, 'min_samples_split': 10, 'min_samples_leaf': 4, 'max_features': None, 'bootstrap': True, 'max_samples': 0.7726456264171515}. Best is trial 13 with value: 0.03643386996991649.
# [I 2026-04-20 21:25:43,362] Trial 14 finished with value: 0.043964612226110915 and parameters: {'n_estimators': 400, 'max_depth': 17, 'min_samples_split': 10, 'min_samples_leaf': 5, 'max_features': 'log2', 'bootstrap': True, 'max_samples': 0.8221437382046897}. Best is trial 13 with value: 0.03643386996991649.
# [I 2026-04-20 21:25:44,906] Trial 15 finished with value: 0.038131849416619894 and parameters: {'n_estimators': 800, 'max_depth': 15, 'min_samples_split': 10, 'min_samples_leaf': 10, 'max_features': None, 'bootstrap': True, 'max_samples': 0.8133381662461365}. Best is trial 13 with value: 0.03643386996991649.
# [I 2026-04-20 21:25:45,728] Trial 16 finished with value: 0.03636884844497147 and parameters: {'n_estimators': 400, 'max_depth': 10, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_features': None, 'bootstrap': True, 'max_samples': 0.5585188301904098}. Best is trial 16 with value: 0.03636884844497147.
# [I 2026-04-20 21:25:47,513] Trial 17 finished with value: 0.036394172275942736 and parameters: {'n_estimators': 900, 'max_depth': 19, 'min_samples_split': 4, 'min_samples_leaf': 4, 'max_features': None, 'bootstrap': True, 'max_samples': 0.5126344663512117}. Best is trial 16 with value: 0.03636884844497147.
# [I 2026-04-20 21:25:48,807] Trial 18 finished with value: 0.04939165767985229 and parameters: {'n_estimators': 700, 'max_depth': 11, 'min_samples_split': 4, 'min_samples_leaf': 9, 'max_features': 'log2', 'bootstrap': True, 'max_samples': 0.501266333313097}. Best is trial 16 with value: 0.03636884844497147.
# [I 2026-04-20 21:25:49,566] Trial 19 finished with value: 0.04691723637550168 and parameters: {'n_estimators': 400, 'max_depth': 19, 'min_samples_split': 4, 'min_samples_leaf': 20, 'max_features': None, 'bootstrap': True, 'max_samples': 0.5779645799816593}. Best is trial 16 with value: 0.03636884844497147.
# [I 2026-04-20 21:25:51,854] Trial 20 finished with value: 0.0364376435856429 and parameters: {'n_estimators': 1200, 'max_depth': 21, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_features': None, 'bootstrap': True, 'max_samples': 0.579593024727031}. Best is trial 16 with value: 0.03636884844497147.
# [I 2026-04-20 21:25:53,654] Trial 21 finished with value: 0.03647796506442455 and parameters: {'n_estimators': 900, 'max_depth': 17, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_features': None, 'bootstrap': True, 'max_samples': 0.7779367017806819}. Best is trial 16 with value: 0.03636884844497147.
# [I 2026-04-20 21:25:55,439] Trial 22 finished with value: 0.03656556301115409 and parameters: {'n_estimators': 900, 'max_depth': 13, 'min_samples_split': 12, 'min_samples_leaf': 3, 'max_features': None, 'bootstrap': True, 'max_samples': 0.5865697539911241}. Best is trial 16 with value: 0.03636884844497147.
# [I 2026-04-20 21:25:56,870] Trial 23 finished with value: 0.036565576290472704 and parameters: {'n_estimators': 700, 'max_depth': 8, 'min_samples_split': 9, 'min_samples_leaf': 5, 'max_features': None, 'bootstrap': True, 'max_samples': 0.8530450577649853}. Best is trial 16 with value: 0.03636884844497147.
# [I 2026-04-20 21:25:59,762] Trial 24 finished with value: 0.03721993535327016 and parameters: {'n_estimators': 1500, 'max_depth': 19, 'min_samples_split': 5, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': True, 'max_samples': 0.6248448658511457}. Best is trial 16 with value: 0.03636884844497147.
# [I 2026-04-20 21:26:01,482] Trial 25 finished with value: 0.043421027173867005 and parameters: {'n_estimators': 900, 'max_depth': 13, 'min_samples_split': 3, 'min_samples_leaf': 3, 'max_features': 'log2', 'bootstrap': True, 'max_samples': 0.5361822591733555}. Best is trial 16 with value: 0.03636884844497147.
# [I 2026-04-20 21:26:03,608] Trial 26 finished with value: 0.03687372506399414 and parameters: {'n_estimators': 1100, 'max_depth': 19, 'min_samples_split': 14, 'min_samples_leaf': 6, 'max_features': None, 'bootstrap': True, 'max_samples': 0.7491613740190971}. Best is trial 16 with value: 0.03636884844497147.
# [I 2026-04-20 21:26:04,844] Trial 27 finished with value: 0.03803022242968976 and parameters: {'n_estimators': 600, 'max_depth': 16, 'min_samples_split': 6, 'min_samples_leaf': 10, 'max_features': None, 'bootstrap': True, 'max_samples': 0.8871931788220069}. Best is trial 16 with value: 0.03636884844497147.
# [I 2026-04-20 21:26:06,787] Trial 28 finished with value: 0.0374324290125363 and parameters: {'n_estimators': 1000, 'max_depth': 8, 'min_samples_split': 9, 'min_samples_leaf': 8, 'max_features': None, 'bootstrap': True, 'max_samples': 0.7431138708724583}. Best is trial 16 with value: 0.03636884844497147.
# [I 2026-04-20 21:26:07,146] Trial 29 finished with value: 0.043458961927027084 and parameters: {'n_estimators': 200, 'max_depth': 12, 'min_samples_split': 14, 'min_samples_leaf': 4, 'max_features': 'log2', 'bootstrap': False}. Best is trial 16 with value: 0.03636884844497147.
# [I 2026-04-20 21:26:07,466] Trial 30 finished with value: 0.04119942223763451 and parameters: {'n_estimators': 100, 'max_depth': 27, 'min_samples_split': 3, 'min_samples_leaf': 12, 'max_features': None, 'bootstrap': True, 'max_samples': 0.5408797149605485}. Best is trial 16 with value: 0.03636884844497147.
# [I 2026-04-20 21:26:09,776] Trial 31 finished with value: 0.03640065331126673 and parameters: {'n_estimators': 1200, 'max_depth': 21, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_features': None, 'bootstrap': True, 'max_samples': 0.6012705493795799}. Best is trial 16 with value: 0.03636884844497147.
# [I 2026-04-20 21:26:12,052] Trial 32 finished with value: 0.03657434835430906 and parameters: {'n_estimators': 1200, 'max_depth': 22, 'min_samples_split': 6, 'min_samples_leaf': 5, 'max_features': None, 'bootstrap': True, 'max_samples': 0.6166645467549243}. Best is trial 16 with value: 0.03636884844497147.
# [I 2026-04-20 21:26:13,584] Trial 33 finished with value: 0.03648488163881787 and parameters: {'n_estimators': 800, 'max_depth': 21, 'min_samples_split': 11, 'min_samples_leaf': 3, 'max_features': None, 'bootstrap': True, 'max_samples': 0.5466042438070433}. Best is trial 16 with value: 0.03636884844497147.
# [I 2026-04-20 21:26:15,683] Trial 34 finished with value: 0.03736189028635211 and parameters: {'n_estimators': 1100, 'max_depth': 24, 'min_samples_split': 8, 'min_samples_leaf': 7, 'max_features': None, 'bootstrap': True, 'max_samples': 0.5969210655263613}. Best is trial 16 with value: 0.03636884844497147.
# [I 2026-04-20 21:26:17,937] Trial 35 finished with value: 0.046060239736022496 and parameters: {'n_estimators': 1200, 'max_depth': 18, 'min_samples_split': 4, 'min_samples_leaf': 6, 'max_features': 'sqrt', 'bootstrap': True, 'max_samples': 0.5447853249237213}. Best is trial 16 with value: 0.03636884844497147.
# [I 2026-04-20 21:26:19,826] Trial 36 finished with value: 0.060446615926592305 and parameters: {'n_estimators': 1500, 'max_depth': 22, 'min_samples_split': 12, 'min_samples_leaf': 2, 'max_features': None, 'bootstrap': False}. Best is trial 16 with value: 0.03636884844497147.
# [I 2026-04-20 21:26:21,374] Trial 37 finished with value: 0.04340513770894007 and parameters: {'n_estimators': 800, 'max_depth': 8, 'min_samples_split': 6, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'bootstrap': True, 'max_samples': 0.6477578307761069}. Best is trial 16 with value: 0.03636884844497147.
# [I 2026-04-20 21:26:22,032] Trial 38 finished with value: 0.037194190013269755 and parameters: {'n_estimators': 300, 'max_depth': 26, 'min_samples_split': 3, 'min_samples_leaf': 8, 'max_features': None, 'bootstrap': True, 'max_samples': 0.9769919663696423}. Best is trial 16 with value: 0.03636884844497147.
# [I 2026-04-20 21:26:23,646] Trial 39 finished with value: 0.04930589786721368 and parameters: {'n_estimators': 1300, 'max_depth': 10, 'min_samples_split': 7, 'min_samples_leaf': 7, 'max_features': None, 'bootstrap': False}. Best is trial 16 with value: 0.03636884844497147.
# [I 2026-04-20 21:26:26,321] Trial 40 finished with value: 0.05340140386440271 and parameters: {'n_estimators': 1400, 'max_depth': 20, 'min_samples_split': 2, 'min_samples_leaf': 17, 'max_features': 'sqrt', 'bootstrap': True, 'max_samples': 0.7112126373325824}. Best is trial 16 with value: 0.03636884844497147.
# [I 2026-04-20 21:26:28,612] Trial 41 finished with value: 0.03644165594309619 and parameters: {'n_estimators': 1200, 'max_depth': 24, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_features': None, 'bootstrap': True, 'max_samples': 0.5686689773888717}. Best is trial 16 with value: 0.03636884844497147.
# [I 2026-04-20 21:26:30,748] Trial 42 finished with value: 0.03653493066258383 and parameters: {'n_estimators': 1100, 'max_depth': 16, 'min_samples_split': 8, 'min_samples_leaf': 4, 'max_features': None, 'bootstrap': True, 'max_samples': 0.629910155271981}. Best is trial 16 with value: 0.03636884844497147.
# [I 2026-04-20 21:26:32,712] Trial 43 finished with value: 0.03633818725778097 and parameters: {'n_estimators': 1000, 'max_depth': 21, 'min_samples_split': 5, 'min_samples_leaf': 3, 'max_features': None, 'bootstrap': True, 'max_samples': 0.5190454811461203}. Best is trial 43 with value: 0.03633818725778097.
# [I 2026-04-20 21:26:34,664] Trial 44 finished with value: 0.03638049597237866 and parameters: {'n_estimators': 1000, 'max_depth': 23, 'min_samples_split': 6, 'min_samples_leaf': 2, 'max_features': None, 'bootstrap': True, 'max_samples': 0.5172654276743363}. Best is trial 43 with value: 0.03633818725778097.
# [I 2026-04-20 21:26:36,056] Trial 45 finished with value: 0.06631795620602751 and parameters: {'n_estimators': 1000, 'max_depth': 22, 'min_samples_split': 6, 'min_samples_leaf': 2, 'max_features': None, 'bootstrap': False}. Best is trial 43 with value: 0.03633818725778097.
# [I 2026-04-20 21:26:38,029] Trial 46 finished with value: 0.03642036606664091 and parameters: {'n_estimators': 1000, 'max_depth': 23, 'min_samples_split': 4, 'min_samples_leaf': 2, 'max_features': None, 'bootstrap': True, 'max_samples': 0.5209645011221731}. Best is trial 43 with value: 0.03633818725778097.
# [I 2026-04-20 21:26:39,271] Trial 47 finished with value: 0.03621549501349304 and parameters: {'n_estimators': 600, 'max_depth': 26, 'min_samples_split': 7, 'min_samples_leaf': 3, 'max_features': None, 'bootstrap': True, 'max_samples': 0.5041681530892771}. Best is trial 47 with value: 0.03621549501349304.
# [I 2026-04-20 21:26:40,282] Trial 48 finished with value: 0.04338003135948828 and parameters: {'n_estimators': 500, 'max_depth': 28, 'min_samples_split': 8, 'min_samples_leaf': 1, 'max_features': 'log2', 'bootstrap': True, 'max_samples': 0.5078934748747439}. Best is trial 47 with value: 0.03621549501349304.
# [I 2026-04-20 21:26:41,284] Trial 49 finished with value: 0.043538146853604874 and parameters: {'n_estimators': 500, 'max_depth': 27, 'min_samples_split': 3, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'bootstrap': True, 'max_samples': 0.5581767959003183}. Best is trial 47 with value: 0.03621549501349304.
# Best trial: 47
# Best MSE: 0.03621549501349304
# Best hyperparameters:
# {'n_estimators': 600, 'max_depth': 26, 'min_samples_split': 7, 'min_samples_leaf': 3, 'max_features': None, 'bootstrap': True, 'max_samples': 0.5041681530892771}

# %% [markdown]
# $\text{RMS} = \sqrt{\frac{1}{N}\sum_{i=1}^{N}(\Delta\mu_i - \Delta\mu_{\rm ML, predict})^2}$

# %%
best_params = study.best_params.copy()
print(best_params)
best_params["n_jobs"] = -1
best_params["random_state"] = 42

rf = RandomForestRegressor(**best_params)
rf.fit(X, y)
y_pred = rf.predict(X)

# RMS of prediction residuals
rms = np.sqrt(np.mean((y.to_numpy() - y_pred) ** 2))

print("RMS:", rms)
# Out:
# {'n_estimators': 600, 'max_depth': 26, 'min_samples_split': 7, 'min_samples_leaf': 3, 'max_features': None, 'bootstrap': True, 'max_samples': 0.5041681530892771}
# RMS: 0.1332406625898228

# %%
# Define the following global parameters:

alpha = 0.161
beta  = 3.05

df["ZTF_mu_obs"] = -2.5 * np.log10(df["ZTF_x0"])

# Define the following cosmology:
cosmo = FlatLambdaCDM(H0=70, Om0=0.3)

# Evaluate the cosmology at the ZTF reported redshift. We are using the ZTF redshift instead of DESI
# b/c we're propagating the ZTF uncertainty and we want to keep everything in the same data set. 

mu_th = cosmo.distmod(df["ZTF_redshift"]).value
corrected_residuals = df["ZTF_mu_obs"] - mu_th - (-29.759687) - y_pred

plt.hist(corrected_residuals)
plt.xlabel(r"$\Delta\mu = -2.5\log x_0 - \mathscr{M} - \mu_{\rm th}$")


rms_corrected = np.sqrt(np.mean(corrected_residuals ** 2))
print("RMS of corrected residuals:", rms_corrected)

feature_importances = pd.Series(rf.feature_importances_, index=feature_cols).sort_values(ascending=False)
print(feature_importances)
# Out:
# RMS of corrected residuals: 0.24456010834816533
# ZTF_c                      0.665169
# ZTF_x1                     0.190976
# DESI_METADATA_Z            0.041596
# DESI_FASTSPEC_DN4000       0.021912
# DESI_FASTSPEC_g_minus_r    0.019726
# DESI_FASTSPEC_AGE          0.017436
# DESI_FASTSPEC_SFR          0.015204
# DESI_FASTSPEC_LOGMSTAR     0.014986
# DESI_FASTSPEC_VDISP        0.012994
# dtype: float64

# %% [markdown]
# ## Why predictions Seem Like they are Capped
#
# The predicted residuals span a much narrower range than the true residuals.
# This is expected behavior when the features carry little predictive signal.
#
# Each Random Forest prediction is the average of `n_predictors` individual tree
# predictions. When the features (host galaxy properties) do not strongly
# determine the target (Hubble residuals), each tree essentially guesses
# near the sample mean. Averaging 1,000 near-zero guesses produces
# predictions tightly clustered around zero.
#
# This is consistent with a null result: host galaxy properties do not
# significantly predict Hubble residuals beyond the Tripp correction.
#
# Input from Dr. Armin Rest this shows evidence that our assumptions about
# the fact that host galaxies give some form of nonlinear non parametric relations/corrections
# to the Hubble residuals.

# %%
plt.figure(figsize=(6, 6))
plt.scatter(y, y_pred, alpha=0.7)
plt.xlabel(r"$\Delta\mu = -2.5\log x_0 - \mathscr{M} - \mu_{\rm th}$")
plt.ylabel(r"$\Delta\mu_{\mathrm{ML}_{\mathrm{predict}}}$")
plt.axline((0, 0), slope=1, linestyle="--")

plt.xlim(-1, 1)
plt.ylim(-1, 1)

plt.tight_layout()
plt.show()
