# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import optuna

from sklearn.model_selection import train_test_split, KFold
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error

# %%
df = pd.read_csv("data/ZTF_DESI_matched_lc_cuts_z_cuts_hostprop_cleaned_tripp_uncorrected.csv")
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 513 entries, 0 to 512
# Data columns (total 69 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   ZTF_Unnamed: 0                    513 non-null    float64
#  1   ztfname                           513 non-null    object
#  2   ZTF_redshift                      513 non-null    float64
#  3   ZTF_redshift_err                  513 non-null    float64
#  4   ZTF_source                        513 non-null    object
#  5   ZTF_t0                            513 non-null    float64
#  6   ZTF_x0                            513 non-null    float64
#  7   ZTF_x1                            513 non-null    float64
#  8   ZTF_c                             513 non-null    float64
#  9   ZTF_t0_err                        513 non-null    float64
#  10  ZTF_x0_err                        513 non-null    float64
#  11  ZTF_x1_err                        513 non-null    float64
#  12  ZTF_c_err                         513 non-null    float64
#  13  ZTF_cov_t0_x0                     513 non-null    float64
#  14  ZTF_cov_t0_x1                     513 non-null    float64
#  15  ZTF_cov_t0_c                      513 non-null    float64
#  16  ZTF_cov_x0_x1                     513 non-null    float64
#  17  ZTF_cov_x0_c                      513 non-null    float64
#  18  ZTF_cov_x1_c                      513 non-null    float64
#  19  ZTF_mwebv                         513 non-null    float64
#  20  ZTF_mwr_v                         513 non-null    float64
#  21  ZTF_mwebv_err                     513 non-null    float64
#  22  ZTF_fitprob                       513 non-null    float64
#  23  ZTF_ra                            513 non-null    float64
#  24  ZTF_dec                           513 non-null    float64
#  25  ZTF_sn_type                       513 non-null    object
#  26  ZTF_sub_type                      431 non-null    object
#  27  ZTF_lccoverage_flag               513 non-null    float64
#  28  ZTF_fitquality_flag               513 non-null    float64
#  29  ZTF_iau_name                      499 non-null    object
#  30  ZTF_frac_fitted                   513 non-null    float64
#  31  ZTF_ra_host_global                513 non-null    float64
#  32  ZTF_dec_host_global               513 non-null    float64
#  33  ZTF_mass_global                   511 non-null    float64
#  34  ZTF_mass_err_global               511 non-null    float64
#  35  ZTF_restframe_gz_global           511 non-null    float64
#  36  ZTF_restframe_gz_err_global       511 non-null    float64
#  37  ZTF_d_dlr_global                  513 non-null    float64
#  38  ZTF_mass_local                    507 non-null    float64
#  39  ZTF_mass_err_local                511 non-null    float64
#  40  ZTF_restframe_gz_local            507 non-null    float64
#  41  ZTF_restframe_gz_err_local        507 non-null    float64
#  42  ZTF_DESI_METADATA_ang_sep_arcsec  513 non-null    float64
#  43  DESI_METADATA_TARGETID            513 non-null    float64
#  44  DESI_METADATA_LS_ID               513 non-null    float64
#  45  DESI_METADATA_SPECTYPE            513 non-null    object
#  46  DESI_METADATA_RA                  513 non-null    float64
#  47  DESI_METADATA_DEC                 513 non-null    float64
#  48  DESI_METADATA_DESI_TARGET         513 non-null    float64
#  49  DESI_METADATA_Z                   513 non-null    float64
#  50  DESI_METADATA_ZWARN               513 non-null    float64
#  51  DESI_METADATA_PROGRAM             513 non-null    object
#  52  DESI_METADATA_SURVEY              513 non-null    object
#  53  DESI_FASTSPEC_TARGETID            513 non-null    float64
#  54  DESI_FASTSPEC_HEALPIX             513 non-null    float64
#  55  DESI_FASTSPEC_VDISP               513 non-null    float64
#  56  DESI_FASTSPEC_VDISP_IVAR          513 non-null    float64
#  57  DESI_FASTSPEC_LOGMSTAR            513 non-null    float64
#  58  DESI_FASTSPEC_SFR                 513 non-null    float64
#  59  DESI_FASTSPEC_AGE                 513 non-null    float64
#  60  DESI_FASTSPEC_DN4000              513 non-null    float64
#  61  DESI_FASTSPEC_DN4000_IVAR         513 non-null    float64
#  62  DESI_FASTSPEC_ABSMAG01_SDSS_G     513 non-null    float64
#  63  DESI_FASTSPEC_ZZSUN               513 non-null    float64
#  64  DESI_FASTSPEC_ABSMAG01_SDSS_R     513 non-null    float64
#  65  DESI_FASTSPEC_g_minus_r           513 non-null    float64
#  66  ZTF_mu_obs                        513 non-null    float64
#  67  ZTF_sigma_mu                      513 non-null    float64
#  68  residuals                         513 non-null    float64
# dtypes: float64(61), object(8)
# memory usage: 276.7+ KB
# None

# %%
feature_cols = [
    "DESI_FASTSPEC_LOGMSTAR",
    "DESI_FASTSPEC_SFR",
    "DESI_FASTSPEC_VDISP",
    "DESI_FASTSPEC_DN4000",
    "DESI_FASTSPEC_g_minus_r",
    "DESI_FASTSPEC_AGE",
    "DESI_METADATA_Z",
    "ZTF_x1",
    "ZTF_c",
]

target_col = "residuals"

yerr_all = df["ZTF_sigma_mu"]

X = df[feature_cols]
y = df[target_col]

# %%
Xtr, Xte, ytr, yte, yerr_tr, yerr_te = train_test_split(
    X, y, yerr_all, test_size=0.2, random_state=42
)

# Optional: convert training pieces to numpy for easier CV indexing
Xtr_np = Xtr.to_numpy()
ytr_np = ytr.to_numpy()
yerr_tr_np = yerr_tr.to_numpy()

# %%
def weighted_rmse(y_true, y_pred, yerr):
    w = 1.0 / (yerr ** 2)
    return np.sqrt(np.sum(w * (y_true - y_pred) ** 2) / np.sum(w))

# %%
def objective(trial):
    params = {
        "n_estimators": trial.suggest_int("n_estimators", 200, 1500, step=100),
        "max_depth": trial.suggest_int("max_depth", 3, 30),
        "min_samples_split": trial.suggest_int("min_samples_split", 2, 20),
        "min_samples_leaf": trial.suggest_int("min_samples_leaf", 1, 10),
        "max_features": trial.suggest_categorical("max_features", ["sqrt", "log2", None]),
        "bootstrap": trial.suggest_categorical("bootstrap", [True, False]),
        "n_jobs": -1,
        "random_state": 42,
    }

    if params["bootstrap"]:
        params["max_samples"] = trial.suggest_float("max_samples", 0.5, 1.0)

    rf = RandomForestRegressor(**params)

    kf = KFold(n_splits=5, shuffle=True, random_state=42)
    fold_scores = []

    for train_idx, val_idx in kf.split(Xtr_np):
        X_fold_tr = Xtr_np[train_idx]
        X_fold_val = Xtr_np[val_idx]

        y_fold_tr = ytr_np[train_idx]
        y_fold_val = ytr_np[val_idx]

        yerr_fold_tr = yerr_tr_np[train_idx]
        yerr_fold_val = yerr_tr_np[val_idx]

        w_fold_tr = 1.0 / (yerr_fold_tr ** 2)

        rf.fit(X_fold_tr, y_fold_tr, sample_weight=w_fold_tr)
        y_fold_pred = rf.predict(X_fold_val)

        score = weighted_rmse(y_fold_val, y_fold_pred, yerr_fold_val)
        fold_scores.append(score)

    return np.mean(fold_scores)

# %%
study = optuna.create_study(direction="minimize")
study.optimize(objective, n_trials=50, show_progress_bar=True)

print("Best trial:", study.best_trial.number)
print("Best weighted CV RMSE:", study.best_value)
print("Best hyperparameters:")
print(study.best_params)
# Out:
# [I 2026-04-07 14:39:54,405] A new study created in memory with name: no-name-bc7c91e8-38fa-4316-9cd8-f2bfdfd6c6ec
#   0%|          | 0/50 [00:00<?, ?it/s]
# [I 2026-04-07 14:39:56,210] Trial 0 finished with value: 0.2087824497111849 and parameters: {'n_estimators': 1300, 'max_depth': 13, 'min_samples_split': 2, 'min_samples_leaf': 9, 'max_features': None, 'bootstrap': False}. Best is trial 0 with value: 0.2087824497111849.
# [I 2026-04-07 14:39:56,651] Trial 1 finished with value: 0.20241566916475834 and parameters: {'n_estimators': 300, 'max_depth': 10, 'min_samples_split': 17, 'min_samples_leaf': 7, 'max_features': 'sqrt', 'bootstrap': False}. Best is trial 1 with value: 0.20241566916475834.
# [I 2026-04-07 14:39:58,108] Trial 2 finished with value: 0.20427675485753277 and parameters: {'n_estimators': 800, 'max_depth': 28, 'min_samples_split': 4, 'min_samples_leaf': 6, 'max_features': 'sqrt', 'bootstrap': True, 'max_samples': 0.7875614315514732}. Best is trial 1 with value: 0.20241566916475834.
# [I 2026-04-07 14:39:59,858] Trial 3 finished with value: 0.2164217202438498 and parameters: {'n_estimators': 1300, 'max_depth': 24, 'min_samples_split': 13, 'min_samples_leaf': 6, 'max_features': None, 'bootstrap': False}. Best is trial 1 with value: 0.20241566916475834.
# [I 2026-04-07 14:40:01,700] Trial 4 finished with value: 0.18323241358671835 and parameters: {'n_estimators': 1000, 'max_depth': 30, 'min_samples_split': 18, 'min_samples_leaf': 8, 'max_features': None, 'bootstrap': True, 'max_samples': 0.6838395375242714}. Best is trial 4 with value: 0.18323241358671835.
# [I 2026-04-07 14:40:03,693] Trial 5 finished with value: 0.20869840162221037 and parameters: {'n_estimators': 1500, 'max_depth': 10, 'min_samples_split': 9, 'min_samples_leaf': 9, 'max_features': None, 'bootstrap': False}. Best is trial 4 with value: 0.18323241358671835.
# [I 2026-04-07 14:40:04,281] Trial 6 finished with value: 0.24320426302201642 and parameters: {'n_estimators': 400, 'max_depth': 14, 'min_samples_split': 19, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': False}. Best is trial 4 with value: 0.18323241358671835.
# [I 2026-04-07 14:40:05,668] Trial 7 finished with value: 0.2703025464205961 and parameters: {'n_estimators': 1000, 'max_depth': 26, 'min_samples_split': 9, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': False}. Best is trial 4 with value: 0.18323241358671835.
# [I 2026-04-07 14:40:06,639] Trial 8 finished with value: 0.20128222501589038 and parameters: {'n_estimators': 500, 'max_depth': 9, 'min_samples_split': 15, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'bootstrap': True, 'max_samples': 0.816373194009885}. Best is trial 4 with value: 0.18323241358671835.
# [I 2026-04-07 14:40:07,829] Trial 9 finished with value: 0.1816658890888092 and parameters: {'n_estimators': 600, 'max_depth': 22, 'min_samples_split': 11, 'min_samples_leaf': 4, 'max_features': None, 'bootstrap': True, 'max_samples': 0.5919293735211484}. Best is trial 9 with value: 0.1816658890888092.
# [I 2026-04-07 14:40:09,126] Trial 10 finished with value: 0.20232422457644766 and parameters: {'n_estimators': 700, 'max_depth': 20, 'min_samples_split': 6, 'min_samples_leaf': 4, 'max_features': 'log2', 'bootstrap': True, 'max_samples': 0.5548315864115971}. Best is trial 9 with value: 0.1816658890888092.
# [I 2026-04-07 14:40:10,951] Trial 11 finished with value: 0.2041787260455929 and parameters: {'n_estimators': 1000, 'max_depth': 30, 'min_samples_split': 12, 'min_samples_leaf': 4, 'max_features': 'log2', 'bootstrap': True, 'max_samples': 0.5709567091738428}. Best is trial 9 with value: 0.1816658890888092.
# [I 2026-04-07 14:40:12,104] Trial 12 finished with value: 0.1928097345418466 and parameters: {'n_estimators': 600, 'max_depth': 3, 'min_samples_split': 20, 'min_samples_leaf': 8, 'max_features': None, 'bootstrap': True, 'max_samples': 0.6414609022421658}. Best is trial 9 with value: 0.1816658890888092.
# [I 2026-04-07 14:40:13,902] Trial 13 finished with value: 0.18470745619622247 and parameters: {'n_estimators': 1000, 'max_depth': 21, 'min_samples_split': 16, 'min_samples_leaf': 10, 'max_features': None, 'bootstrap': True, 'max_samples': 0.6797977474611091}. Best is trial 9 with value: 0.1816658890888092.
# [I 2026-04-07 14:40:14,398] Trial 14 finished with value: 0.18287897254944688 and parameters: {'n_estimators': 200, 'max_depth': 22, 'min_samples_split': 9, 'min_samples_leaf': 4, 'max_features': None, 'bootstrap': True, 'max_samples': 0.9560589813828976}. Best is trial 9 with value: 0.1816658890888092.
# [I 2026-04-07 14:40:14,820] Trial 15 finished with value: 0.19835095078281412 and parameters: {'n_estimators': 200, 'max_depth': 20, 'min_samples_split': 9, 'min_samples_leaf': 3, 'max_features': 'log2', 'bootstrap': True, 'max_samples': 0.9558865505438754}. Best is trial 9 with value: 0.1816658890888092.
# [I 2026-04-07 14:40:15,295] Trial 16 finished with value: 0.1827672887607462 and parameters: {'n_estimators': 200, 'max_depth': 17, 'min_samples_split': 7, 'min_samples_leaf': 4, 'max_features': None, 'bootstrap': True, 'max_samples': 0.9669969797226127}. Best is trial 9 with value: 0.1816658890888092.
# [I 2026-04-07 14:40:16,312] Trial 17 finished with value: 0.1822773237138447 and parameters: {'n_estimators': 500, 'max_depth': 16, 'min_samples_split': 6, 'min_samples_leaf': 5, 'max_features': None, 'bootstrap': True, 'max_samples': 0.8628432046842059}. Best is trial 9 with value: 0.1816658890888092.
# [I 2026-04-07 14:40:17,308] Trial 18 finished with value: 0.196984460582173 and parameters: {'n_estimators': 500, 'max_depth': 15, 'min_samples_split': 6, 'min_samples_leaf': 2, 'max_features': 'log2', 'bootstrap': True, 'max_samples': 0.875622942997417}. Best is trial 9 with value: 0.1816658890888092.
# [I 2026-04-07 14:40:18,600] Trial 19 finished with value: 0.20772208083203836 and parameters: {'n_estimators': 700, 'max_depth': 18, 'min_samples_split': 13, 'min_samples_leaf': 5, 'max_features': 'sqrt', 'bootstrap': True, 'max_samples': 0.5052854042757414}. Best is trial 9 with value: 0.1816658890888092.
# [I 2026-04-07 14:40:19,360] Trial 20 finished with value: 0.18209344777600103 and parameters: {'n_estimators': 400, 'max_depth': 24, 'min_samples_split': 2, 'min_samples_leaf': 5, 'max_features': None, 'bootstrap': True, 'max_samples': 0.8552370950381395}. Best is trial 9 with value: 0.1816658890888092.
# [I 2026-04-07 14:40:20,146] Trial 21 finished with value: 0.18242184233801484 and parameters: {'n_estimators': 400, 'max_depth': 24, 'min_samples_split': 2, 'min_samples_leaf': 5, 'max_features': None, 'bootstrap': True, 'max_samples': 0.8745367618727036}. Best is trial 9 with value: 0.1816658890888092.
# [I 2026-04-07 14:40:21,325] Trial 22 finished with value: 0.1827175832892636 and parameters: {'n_estimators': 600, 'max_depth': 24, 'min_samples_split': 4, 'min_samples_leaf': 6, 'max_features': None, 'bootstrap': True, 'max_samples': 0.8742139440934767}. Best is trial 9 with value: 0.1816658890888092.
# [I 2026-04-07 14:40:22,171] Trial 23 finished with value: 0.18151904851477685 and parameters: {'n_estimators': 400, 'max_depth': 18, 'min_samples_split': 5, 'min_samples_leaf': 3, 'max_features': None, 'bootstrap': True, 'max_samples': 0.7401482496351833}. Best is trial 23 with value: 0.18151904851477685.
# [I 2026-04-07 14:40:23,008] Trial 24 finished with value: 0.18141974716532563 and parameters: {'n_estimators': 400, 'max_depth': 26, 'min_samples_split': 4, 'min_samples_leaf': 3, 'max_features': None, 'bootstrap': True, 'max_samples': 0.7372704553652802}. Best is trial 24 with value: 0.18141974716532563.
# [I 2026-04-07 14:40:24,544] Trial 25 finished with value: 0.18212295697091674 and parameters: {'n_estimators': 800, 'max_depth': 26, 'min_samples_split': 4, 'min_samples_leaf': 2, 'max_features': None, 'bootstrap': True, 'max_samples': 0.7447855093275276}. Best is trial 24 with value: 0.18141974716532563.
# [I 2026-04-07 14:40:25,184] Trial 26 finished with value: 0.18086028641166466 and parameters: {'n_estimators': 300, 'max_depth': 19, 'min_samples_split': 11, 'min_samples_leaf': 3, 'max_features': None, 'bootstrap': True, 'max_samples': 0.7223183476845195}. Best is trial 26 with value: 0.18086028641166466.
# [I 2026-04-07 14:40:25,831] Trial 27 finished with value: 0.18181983564428153 and parameters: {'n_estimators': 300, 'max_depth': 12, 'min_samples_split': 7, 'min_samples_leaf': 2, 'max_features': None, 'bootstrap': True, 'max_samples': 0.7396175359449316}. Best is trial 26 with value: 0.18086028641166466.
# [I 2026-04-07 14:40:26,434] Trial 28 finished with value: 0.1990496737533538 and parameters: {'n_estimators': 300, 'max_depth': 18, 'min_samples_split': 4, 'min_samples_leaf': 3, 'max_features': 'log2', 'bootstrap': True, 'max_samples': 0.7076393477973832}. Best is trial 26 with value: 0.18086028641166466.
# [I 2026-04-07 14:40:27,083] Trial 29 finished with value: 0.1984991490342189 and parameters: {'n_estimators': 400, 'max_depth': 12, 'min_samples_split': 3, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'bootstrap': False}. Best is trial 26 with value: 0.18086028641166466.
# [I 2026-04-07 14:40:29,301] Trial 30 finished with value: 0.1926291076017113 and parameters: {'n_estimators': 1200, 'max_depth': 3, 'min_samples_split': 15, 'min_samples_leaf': 3, 'max_features': None, 'bootstrap': True, 'max_samples': 0.6446807373684255}. Best is trial 26 with value: 0.18086028641166466.
# [I 2026-04-07 14:40:30,511] Trial 31 finished with value: 0.18184827437327206 and parameters: {'n_estimators': 600, 'max_depth': 22, 'min_samples_split': 11, 'min_samples_leaf': 3, 'max_features': None, 'bootstrap': True, 'max_samples': 0.7912620793365259}. Best is trial 26 with value: 0.18086028641166466.
# [I 2026-04-07 14:40:31,173] Trial 32 finished with value: 0.1812029861014638 and parameters: {'n_estimators': 300, 'max_depth': 26, 'min_samples_split': 11, 'min_samples_leaf': 4, 'max_features': None, 'bootstrap': True, 'max_samples': 0.6287568608361198}. Best is trial 26 with value: 0.18086028641166466.
# [I 2026-04-07 14:40:31,815] Trial 33 finished with value: 0.18211943377971634 and parameters: {'n_estimators': 300, 'max_depth': 27, 'min_samples_split': 10, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': True, 'max_samples': 0.7088221762591225}. Best is trial 26 with value: 0.18086028641166466.
# [I 2026-04-07 14:40:32,164] Trial 34 finished with value: 0.254728337275414 and parameters: {'n_estimators': 200, 'max_depth': 28, 'min_samples_split': 7, 'min_samples_leaf': 2, 'max_features': None, 'bootstrap': False}. Best is trial 26 with value: 0.18086028641166466.
# [I 2026-04-07 14:40:32,774] Trial 35 finished with value: 0.20372815110331066 and parameters: {'n_estimators': 300, 'max_depth': 20, 'min_samples_split': 14, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'bootstrap': True, 'max_samples': 0.649030697232459}. Best is trial 26 with value: 0.18086028641166466.
# [I 2026-04-07 14:40:33,796] Trial 36 finished with value: 0.18151396080651294 and parameters: {'n_estimators': 500, 'max_depth': 29, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_features': None, 'bootstrap': True, 'max_samples': 0.6077935132199836}. Best is trial 26 with value: 0.18086028641166466.
# [I 2026-04-07 14:40:34,515] Trial 37 finished with value: 0.2171013664443282 and parameters: {'n_estimators': 500, 'max_depth': 30, 'min_samples_split': 8, 'min_samples_leaf': 6, 'max_features': None, 'bootstrap': False}. Best is trial 26 with value: 0.18086028641166466.
# [I 2026-04-07 14:40:35,133] Trial 38 finished with value: 0.18166664190675513 and parameters: {'n_estimators': 300, 'max_depth': 28, 'min_samples_split': 12, 'min_samples_leaf': 4, 'max_features': None, 'bootstrap': True, 'max_samples': 0.5994062720079218}. Best is trial 26 with value: 0.18086028641166466.
# [I 2026-04-07 14:40:36,107] Trial 39 finished with value: 0.1982336128948187 and parameters: {'n_estimators': 700, 'max_depth': 26, 'min_samples_split': 10, 'min_samples_leaf': 5, 'max_features': 'sqrt', 'bootstrap': False}. Best is trial 26 with value: 0.18086028641166466.
# [I 2026-04-07 14:40:37,813] Trial 40 finished with value: 0.18187219322116405 and parameters: {'n_estimators': 900, 'max_depth': 29, 'min_samples_split': 3, 'min_samples_leaf': 6, 'max_features': None, 'bootstrap': True, 'max_samples': 0.6221660474218715}. Best is trial 26 with value: 0.18086028641166466.
# [I 2026-04-07 14:40:38,626] Trial 41 finished with value: 0.182059570564185 and parameters: {'n_estimators': 400, 'max_depth': 26, 'min_samples_split': 5, 'min_samples_leaf': 3, 'max_features': None, 'bootstrap': True, 'max_samples': 0.7896325646855311}. Best is trial 26 with value: 0.18086028641166466.
# [I 2026-04-07 14:40:39,444] Trial 42 finished with value: 0.18101772309998482 and parameters: {'n_estimators': 400, 'max_depth': 25, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_features': None, 'bootstrap': True, 'max_samples': 0.7295067967085266}. Best is trial 26 with value: 0.18086028641166466.
# [I 2026-04-07 14:40:40,468] Trial 43 finished with value: 0.1813915306745277 and parameters: {'n_estimators': 500, 'max_depth': 25, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_features': None, 'bootstrap': True, 'max_samples': 0.6920063452467968}. Best is trial 26 with value: 0.18086028641166466.
# [I 2026-04-07 14:40:40,949] Trial 44 finished with value: 0.1826395347255818 and parameters: {'n_estimators': 200, 'max_depth': 23, 'min_samples_split': 8, 'min_samples_leaf': 7, 'max_features': None, 'bootstrap': True, 'max_samples': 0.6861265999697007}. Best is trial 26 with value: 0.18086028641166466.
# [I 2026-04-07 14:40:41,590] Trial 45 finished with value: 0.18113035647648684 and parameters: {'n_estimators': 300, 'max_depth': 25, 'min_samples_split': 3, 'min_samples_leaf': 4, 'max_features': None, 'bootstrap': True, 'max_samples': 0.7687566818180357}. Best is trial 26 with value: 0.18086028641166466.
# [I 2026-04-07 14:40:44,407] Trial 46 finished with value: 0.18235234995110444 and parameters: {'n_estimators': 1500, 'max_depth': 25, 'min_samples_split': 18, 'min_samples_leaf': 4, 'max_features': None, 'bootstrap': True, 'max_samples': 0.8216783374447707}. Best is trial 26 with value: 0.18086028641166466.
# [I 2026-04-07 14:40:44,865] Trial 47 finished with value: 0.1977109500801448 and parameters: {'n_estimators': 300, 'max_depth': 23, 'min_samples_split': 3, 'min_samples_leaf': 4, 'max_features': 'log2', 'bootstrap': False}. Best is trial 26 with value: 0.18086028641166466.
# [I 2026-04-07 14:40:45,321] Trial 48 finished with value: 0.18166974807612482 and parameters: {'n_estimators': 200, 'max_depth': 21, 'min_samples_split': 13, 'min_samples_leaf': 5, 'max_features': None, 'bootstrap': True, 'max_samples': 0.770873854547196}. Best is trial 26 with value: 0.18086028641166466.
# [I 2026-04-07 14:40:47,773] Trial 49 finished with value: 0.1811629213624159 and parameters: {'n_estimators': 1300, 'max_depth': 27, 'min_samples_split': 11, 'min_samples_leaf': 4, 'max_features': None, 'bootstrap': True, 'max_samples': 0.7039281384541743}. Best is trial 26 with value: 0.18086028641166466.
# Best trial: 26
# Best weighted CV RMSE: 0.18086028641166466
# Best hyperparameters:
# {'n_estimators': 300, 'max_depth': 19, 'min_samples_split': 11, 'min_samples_leaf': 3, 'max_features': None, 'bootstrap': True, 'max_samples': 0.7223183476845195}

# %%
best_params = study.best_params.copy()
best_params["n_jobs"] = -1
best_params["random_state"] = 42

rf = RandomForestRegressor(**best_params)

w = 1.0 / (yerr_tr.to_numpy() ** 2)

rf.fit(Xtr, ytr, sample_weight=w)
yhat = rf.predict(Xte)

# %%
test_weighted_rmse = weighted_rmse(yte.to_numpy(), yhat, yerr_te.to_numpy())
test_rmse = np.sqrt(mean_squared_error(yte, yhat))

print("Test weighted RMSE:", test_weighted_rmse)
print("Test RMSE:", test_rmse)
# Out:
# Test weighted RMSE: 0.16126528900694254
# Test RMSE: 0.1700250908570673

# %%
print("Feature Importances:")
feature_importances = pd.Series(rf.feature_importances_, index=feature_cols)
print(feature_importances.sort_values(ascending=False))
# Out:
# Feature Importances:
# ZTF_c                      0.657457
# ZTF_x1                     0.210893
# DESI_METADATA_Z            0.046888
# DESI_FASTSPEC_g_minus_r    0.020715
# DESI_FASTSPEC_DN4000       0.018149
# DESI_FASTSPEC_LOGMSTAR     0.013114
# DESI_FASTSPEC_SFR          0.011386
# DESI_FASTSPEC_AGE          0.011270
# DESI_FASTSPEC_VDISP        0.010128
# dtype: float64

# %%
plt.figure(figsize=(6, 6))
plt.scatter(yte, yhat, alpha=0.7)
plt.xlabel("True residuals")
plt.ylabel("Predicted residuals")
plt.axline((0, 0), slope=1, linestyle="--")

plt.xlim(-1, 1)
plt.ylim(-1, 1)

plt.tight_layout()
plt.show()

# %% [markdown]
# # Helper Function That Plots The Scatter with Error Bars #
#
#
# Note that there is now a new way to bin the data here:
#
#
# ### Binned residuals and bin-level error bars
#
# For each host-galaxy variable $x$, we bin the data into $N_{\rm bin}$ intervals along the $x$-axis. In bin $k$, let the set of supernova Hubble residuals be $\{\Delta\mu_i\}_{i=1}^{N_k}$, where $N_k$ is the number of objects in that bin. We plot the binned point as the mean residual in the bin,
#
# $
# \overline{\Delta\mu}_k=\frac{1}{N_k}\sum_{i=1}^{N_k}\Delta\mu_i,
# $
#
# evaluated at the bin center
#
# $
# x_k = \frac{1}{2}\left(x_{k,\min}+x_{k,\max}\right).
# $
#
# To represent the *spread* of residuals within each bin (rather than the uncertainty on the mean), the error bar for bin $k$ is taken to be the sample standard deviation of the residuals in that bin,
#
# $
# \sigma_{k,\rm bin}=\sqrt{\frac{1}{N_k-1}\sum_{i=1}^{N_k}\left(\Delta\mu_i-\overline{\Delta\mu}_k\right)^2}.
# $
#
# This choice yields error bars that reflect the intrinsic dispersion (plus measurement scatter) of $\Delta\mu$ among supernovae within each $x$-bin, and therefore does not shrink artificially as $N_k$ becomes large (in contrast to the standard error on the mean, $\sigma_{\overline{\Delta\mu}} \propto 1/\sqrt{N_k}$).

# %%
# Helper funciton that plots the scatter and error bars. 
# ax - matplotlib axis where the plots will be drawn. 
# mask - the mask that selects which rows to use. 
# xcol - name of the df collumn to put on the x axis. Note residuals are always on the y-axis here.

nbins = 10

def scatter_with_errors(ax, xcol, nbins=None, xerr_col=None, xerr_direct_col=None):

    # Raw values
    x = df[xcol]
    y = df["residuals"]
    yerr = df["ZTF_sigma_mu"]
    
    # Optional horizontal error bars
    if xerr_col is not None:
        xerr = 1.0 / np.sqrt(df[xerr_col])
    # accomodation function for when the xerr is already directly given
    # as part of the SALT2 Curve data release. 
    elif xerr_direct_col is not None: 
        xerr = df[xerr_direct_col]
    else:
        xerr = None #has to be parsed or will crash errorbar function.

    # --- sigma clipping in y (vertical axis) ---
    # NOTE: sigma clipping has been moved OUTSIDE this function.
    # This function now assumes `mask` already includes whatever global sigma-clip
    # (or other cleaning) you want. In other words: this function only plots.
    #
    # UPDATE: we no longer pass a mask into this function because we now DROP
    # any unwanted rows upstream (sigma-clip + physical cuts). Therefore the
    # dataframe `df` is already the final cleaned sample when this function is called.

    # --- scatter cloud ---
    ax.scatter(x, y, **point_kwargs)

    # --- individual error bars ---
    # Important to note that the way that this function works we will be drawing
    # an error bar line from y - yerr to y + yerr. Where y_err = sigma_i
    ax.errorbar(
        x, y, yerr=yerr, xerr = xerr,
        fmt="none",
        ecolor="black",
        elinewidth=0.5,
        alpha=0.25,
        zorder=2,
    )

    # horizontal reference
    ax.axhline(0, linestyle="--", color="orange")

    # --- BINNING WITH ERROR PROPAGATION ---
    # NOTE: we set the number of bins here.

    # binned_statistic is a function tha takes (x, values, ststics, bins, range)
    # x - an array of positions along the x-axis.
    # values - the vaules on which the statistics are computed inside each bin.
    # NOTE: here we want to just count the number of points in each bin on the
    # horizontal axis of our plots. Therefore we parse "x" as both the argument and the
    # value and simply choose "count" as our statistics option.
    # bin_edges is an array of bin boundaries
    # binnumber - the index for which data point each bin belongs in.
    # This is done mostly becaue the data on the horizontal axis is not ranked so
    # we have to give it an identifier when we do our bin statistics later on.
    # Bin centers are just calcualted as the middle points between one bin edge and another.
    _, bin_edges, binnumber = binned_statistic(x, x, statistic="count", bins=nbins)
    bin_centers = 0.5 * (bin_edges[:-1] + bin_edges[1:])

    # Creating arrays for ht residuals.
    binned_y = []
    binned_yerr = []

    # Just a fancy way of saying "for each bin"
    # We end up appending the data and error means into
    # an array.
    for i in range(1, len(bin_edges)):
        in_bin = binnumber == i

        # If a bin is empty, skip it (avoid divide-by-zero)
        if np.sum(in_bin) == 0:
            binned_y.append(np.nan)
            binned_yerr.append(np.nan)
            continue

        # We end up finding data and errro associated
        # with the number of bin that we are in.
        y_bin = y[in_bin]
        err_bin = yerr[in_bin]

        # inverse-variance weights
        w = 1.0 / (err_bin**2)

        # weighted mean
        y_mean = np.sum(w * y_bin) / np.sum(w)

        # propagated error on the mean
        y_mean = np.mean(y_bin)
        err_spread = np.std(y_bin, ddof=1)   # spread of points in the bin
        
        binned_y.append(y_mean)
        binned_yerr.append(err_spread)

    # Convert to arrays and only plot finite bins
    binned_y = np.array(binned_y)
    binned_yerr = np.array(binned_yerr)
    ok = np.isfinite(binned_y) & np.isfinite(binned_yerr)

    ax.errorbar(
        bin_centers[ok],
        binned_y[ok],
        yerr=binned_yerr[ok],
        fmt="o",
        color="blue",
        markersize=7,
        capsize=3,
        zorder=5  # Keeps the data looking on top
    )

# %% [markdown]
# # Read in Our Data Frame #

# %%
df = pd.read_csv("data/ZTF_DESI_matched_lc_cuts_z_cuts_hostprop_cleaned.csv")

print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 521 entries, 0 to 520
# Data columns (total 69 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   ZTF_Unnamed: 0                    521 non-null    float64
#  1   ztfname                           521 non-null    object
#  2   ZTF_redshift                      521 non-null    float64
#  3   ZTF_redshift_err                  521 non-null    float64
#  4   ZTF_source                        521 non-null    object
#  5   ZTF_t0                            521 non-null    float64
#  6   ZTF_x0                            521 non-null    float64
#  7   ZTF_x1                            521 non-null    float64
#  8   ZTF_c                             521 non-null    float64
#  9   ZTF_t0_err                        521 non-null    float64
#  10  ZTF_x0_err                        521 non-null    float64
#  11  ZTF_x1_err                        521 non-null    float64
#  12  ZTF_c_err                         521 non-null    float64
#  13  ZTF_cov_t0_x0                     521 non-null    float64
#  14  ZTF_cov_t0_x1                     521 non-null    float64
#  15  ZTF_cov_t0_c                      521 non-null    float64
#  16  ZTF_cov_x0_x1                     521 non-null    float64
#  17  ZTF_cov_x0_c                      521 non-null    float64
#  18  ZTF_cov_x1_c                      521 non-null    float64
#  19  ZTF_mwebv                         521 non-null    float64
#  20  ZTF_mwr_v                         521 non-null    float64
#  21  ZTF_mwebv_err                     521 non-null    float64
#  22  ZTF_fitprob                       521 non-null    float64
#  23  ZTF_ra                            521 non-null    float64
#  24  ZTF_dec                           521 non-null    float64
#  25  ZTF_sn_type                       521 non-null    object
#  26  ZTF_sub_type                      438 non-null    object
#  27  ZTF_lccoverage_flag               521 non-null    float64
#  28  ZTF_fitquality_flag               521 non-null    float64
#  29  ZTF_iau_name                      507 non-null    object
#  30  ZTF_frac_fitted                   521 non-null    float64
#  31  ZTF_ra_host_global                521 non-null    float64
#  32  ZTF_dec_host_global               521 non-null    float64
#  33  ZTF_mass_global                   519 non-null    float64
#  34  ZTF_mass_err_global               519 non-null    float64
#  35  ZTF_restframe_gz_global           519 non-null    float64
#  36  ZTF_restframe_gz_err_global       519 non-null    float64
#  37  ZTF_d_dlr_global                  521 non-null    float64
#  38  ZTF_mass_local                    515 non-null    float64
#  39  ZTF_mass_err_local                519 non-null    float64
#  40  ZTF_restframe_gz_local            515 non-null    float64
#  41  ZTF_restframe_gz_err_local        515 non-null    float64
#  42  ZTF_DESI_METADATA_ang_sep_arcsec  521 non-null    float64
#  43  DESI_METADATA_TARGETID            521 non-null    float64
#  44  DESI_METADATA_LS_ID               521 non-null    float64
#  45  DESI_METADATA_SPECTYPE            521 non-null    object
#  46  DESI_METADATA_RA                  521 non-null    float64
#  47  DESI_METADATA_DEC                 521 non-null    float64
#  48  DESI_METADATA_DESI_TARGET         521 non-null    float64
#  49  DESI_METADATA_Z                   521 non-null    float64
#  50  DESI_METADATA_ZWARN               521 non-null    float64
#  51  DESI_METADATA_PROGRAM             521 non-null    object
#  52  DESI_METADATA_SURVEY              521 non-null    object
#  53  DESI_FASTSPEC_TARGETID            521 non-null    float64
#  54  DESI_FASTSPEC_HEALPIX             521 non-null    float64
#  55  DESI_FASTSPEC_VDISP               521 non-null    float64
#  56  DESI_FASTSPEC_VDISP_IVAR          521 non-null    float64
#  57  DESI_FASTSPEC_LOGMSTAR            521 non-null    float64
#  58  DESI_FASTSPEC_SFR                 521 non-null    float64
#  59  DESI_FASTSPEC_AGE                 521 non-null    float64
#  60  DESI_FASTSPEC_DN4000              521 non-null    float64
#  61  DESI_FASTSPEC_DN4000_IVAR         521 non-null    float64
#  62  DESI_FASTSPEC_ABSMAG01_SDSS_G     521 non-null    float64
#  63  DESI_FASTSPEC_ZZSUN               521 non-null    float64
#  64  DESI_FASTSPEC_ABSMAG01_SDSS_R     521 non-null    float64
#  65  DESI_FASTSPEC_g_minus_r           521 non-null    float64
#  66  ZTF_mu_obs                        521 non-null    float64
#  67  ZTF_sigma_mu                      521 non-null    float64
#  68  residuals                         521 non-null    float64
# dtypes: float64(61), object(8)
# memory usage: 281.0+ KB
# None

# %% [markdown]
# # Define Our Random Forest Classifier #

# %%
# =====================================================
# MI DAI ML TRAINING BLOCK 
# =====================================================

# Constructing the Random Forest Regressor Model
# Nothing is being fit here, uts just being made.

# Key properties of this model:
# - 1000 trees. 
# - Trees are allowed to grow deep (no max depth)
# - A minimum number of samples per leaf (5) enforces
#   local averaging and limits overfitting
# - At each split, only a subset of features is considered
#   (sqrt of total), encouraging diverse tree structures
# - Bootstrap resampling ensures each tree sees a slightly
#   different realization of the data

rf = RandomForestRegressor(
    n_estimators=1000,
    max_depth=None,
    min_samples_leaf=5,
    max_features="sqrt",
    bootstrap=True,
    n_jobs=-1,
    random_state=42,
 )

# Defining Features and Setting Up Our Train/Test Split

feature_cols = [
    "DESI_FASTSPEC_LOGMSTAR",
    "DESI_FASTSPEC_SFR",
    "DESI_FASTSPEC_VDISP",
    "DESI_FASTSPEC_DN4000",
    "DESI_FASTSPEC_g_minus_r",
    "DESI_FASTSPEC_AGE",
    "DESI_METADATA_Z"
]

target_col = "residuals"

# Target Errors
yerr_all = df["ZTF_sigma_mu"]


X = df[feature_cols]
y = df[target_col]


# -----------------------------------------------------
# Train / test split
# -----------------------------------------------------
# NOTE: we split X, y, *and* yerr together so that
# the measurement errors stay perfectly aligned with
# the training and testing samples.

Xtr, Xte, ytr, yte, yerr_tr, yerr_te = train_test_split(
    X, y, yerr_all, test_size=0.2, random_state=42
)

# -----------------------------------------------------
# Defining standard error as well as weights and fitting the model
# -----------------------------------------------------
# In real code each data point would have its own weight to contribute to the fit.
# NOTE: in this dataset we DO have per-point errors (sigma_mu_meas),
# so we use inverse-variance weighting here.
# NOTE: the random forest algorythm does not take into account the uncertainties of training data. 
# In our case, we are telling the RF classifier to trust percisely fit SNIa more than those 
# with larger propagated uncertainties. 

w = 1.0 / (yerr_tr**2)

rf.fit(Xtr, ytr, sample_weight=w)
yhat = rf.predict(Xte)

print("Feature Importances:")
feature_importances = pd.Series(rf.feature_importances_, index=feature_cols)
print(feature_importances.sort_values(ascending=False))
# Out:
# Feature Importances:
# DESI_FASTSPEC_g_minus_r    0.227865
# DESI_FASTSPEC_DN4000       0.180796
# DESI_METADATA_Z            0.160108
# DESI_FASTSPEC_AGE          0.136443
# DESI_FASTSPEC_LOGMSTAR     0.136004
# DESI_FASTSPEC_VDISP        0.082890
# DESI_FASTSPEC_SFR          0.075894
# dtype: float64
