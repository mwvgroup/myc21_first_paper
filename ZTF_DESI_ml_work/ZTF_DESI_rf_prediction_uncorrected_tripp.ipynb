# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import optuna

from sklearn.model_selection import train_test_split, KFold
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error

# %%
df = pd.read_csv("data/ZTF_DESI_matched_lc_cuts_z_cuts_hostprop_cleaned_tripp_uncorrected.csv")
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 513 entries, 0 to 512
# Data columns (total 69 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   ZTF_Unnamed: 0                    513 non-null    float64
#  1   ztfname                           513 non-null    object
#  2   ZTF_redshift                      513 non-null    float64
#  3   ZTF_redshift_err                  513 non-null    float64
#  4   ZTF_source                        513 non-null    object
#  5   ZTF_t0                            513 non-null    float64
#  6   ZTF_x0                            513 non-null    float64
#  7   ZTF_x1                            513 non-null    float64
#  8   ZTF_c                             513 non-null    float64
#  9   ZTF_t0_err                        513 non-null    float64
#  10  ZTF_x0_err                        513 non-null    float64
#  11  ZTF_x1_err                        513 non-null    float64
#  12  ZTF_c_err                         513 non-null    float64
#  13  ZTF_cov_t0_x0                     513 non-null    float64
#  14  ZTF_cov_t0_x1                     513 non-null    float64
#  15  ZTF_cov_t0_c                      513 non-null    float64
#  16  ZTF_cov_x0_x1                     513 non-null    float64
#  17  ZTF_cov_x0_c                      513 non-null    float64
#  18  ZTF_cov_x1_c                      513 non-null    float64
#  19  ZTF_mwebv                         513 non-null    float64
#  20  ZTF_mwr_v                         513 non-null    float64
#  21  ZTF_mwebv_err                     513 non-null    float64
#  22  ZTF_fitprob                       513 non-null    float64
#  23  ZTF_ra                            513 non-null    float64
#  24  ZTF_dec                           513 non-null    float64
#  25  ZTF_sn_type                       513 non-null    object
#  26  ZTF_sub_type                      431 non-null    object
#  27  ZTF_lccoverage_flag               513 non-null    float64
#  28  ZTF_fitquality_flag               513 non-null    float64
#  29  ZTF_iau_name                      499 non-null    object
#  30  ZTF_frac_fitted                   513 non-null    float64
#  31  ZTF_ra_host_global                513 non-null    float64
#  32  ZTF_dec_host_global               513 non-null    float64
#  33  ZTF_mass_global                   511 non-null    float64
#  34  ZTF_mass_err_global               511 non-null    float64
#  35  ZTF_restframe_gz_global           511 non-null    float64
#  36  ZTF_restframe_gz_err_global       511 non-null    float64
#  37  ZTF_d_dlr_global                  513 non-null    float64
#  38  ZTF_mass_local                    507 non-null    float64
#  39  ZTF_mass_err_local                511 non-null    float64
#  40  ZTF_restframe_gz_local            507 non-null    float64
#  41  ZTF_restframe_gz_err_local        507 non-null    float64
#  42  ZTF_DESI_METADATA_ang_sep_arcsec  513 non-null    float64
#  43  DESI_METADATA_TARGETID            513 non-null    float64
#  44  DESI_METADATA_LS_ID               513 non-null    float64
#  45  DESI_METADATA_SPECTYPE            513 non-null    object
#  46  DESI_METADATA_RA                  513 non-null    float64
#  47  DESI_METADATA_DEC                 513 non-null    float64
#  48  DESI_METADATA_DESI_TARGET         513 non-null    float64
#  49  DESI_METADATA_Z                   513 non-null    float64
#  50  DESI_METADATA_ZWARN               513 non-null    float64
#  51  DESI_METADATA_PROGRAM             513 non-null    object
#  52  DESI_METADATA_SURVEY              513 non-null    object
#  53  DESI_FASTSPEC_TARGETID            513 non-null    float64
#  54  DESI_FASTSPEC_HEALPIX             513 non-null    float64
#  55  DESI_FASTSPEC_VDISP               513 non-null    float64
#  56  DESI_FASTSPEC_VDISP_IVAR          513 non-null    float64
#  57  DESI_FASTSPEC_LOGMSTAR            513 non-null    float64
#  58  DESI_FASTSPEC_SFR                 513 non-null    float64
#  59  DESI_FASTSPEC_AGE                 513 non-null    float64
#  60  DESI_FASTSPEC_DN4000              513 non-null    float64
#  61  DESI_FASTSPEC_DN4000_IVAR         513 non-null    float64
#  62  DESI_FASTSPEC_ABSMAG01_SDSS_G     513 non-null    float64
#  63  DESI_FASTSPEC_ZZSUN               513 non-null    float64
#  64  DESI_FASTSPEC_ABSMAG01_SDSS_R     513 non-null    float64
#  65  DESI_FASTSPEC_g_minus_r           513 non-null    float64
#  66  ZTF_mu_obs                        513 non-null    float64
#  67  ZTF_sigma_mu                      513 non-null    float64
#  68  residuals                         513 non-null    float64
# dtypes: float64(61), object(8)
# memory usage: 276.7+ KB
# None

# %%
feature_cols = [
    "DESI_FASTSPEC_LOGMSTAR",
    "DESI_FASTSPEC_SFR",
    "DESI_FASTSPEC_VDISP",
    "DESI_FASTSPEC_DN4000",
    "DESI_FASTSPEC_g_minus_r",
    "DESI_FASTSPEC_AGE",
    "DESI_METADATA_Z",
    "ZTF_x1",
    "ZTF_c",
]

target_col = "residuals"

yerr_all = df["ZTF_sigma_mu"]

X = df[feature_cols]
y = df[target_col]

# %%
Xtr, Xte, ytr, yte, yerr_tr, yerr_te = train_test_split(
    X, y, yerr_all, test_size=0.2, random_state=42
)

# Optional: convert training pieces to numpy for easier CV indexing
Xtr_np = Xtr.to_numpy()
ytr_np = ytr.to_numpy()
yerr_tr_np = yerr_tr.to_numpy()

# %%
def weighted_rmse(y_true, y_pred, yerr):
    w = 1.0 / (yerr ** 2)
    return np.sqrt(np.sum(w * (y_true - y_pred) ** 2) / np.sum(w))

# %%
def objective(trial):
    params = {
        "n_estimators": trial.suggest_int("n_estimators", 200, 1500, step=100),
        "max_depth": trial.suggest_int("max_depth", 3, 30),
        "min_samples_split": trial.suggest_int("min_samples_split", 2, 20),
        "min_samples_leaf": trial.suggest_int("min_samples_leaf", 1, 10),
        "max_features": trial.suggest_categorical("max_features", ["sqrt", "log2", None]),
        "bootstrap": trial.suggest_categorical("bootstrap", [True, False]),
        "n_jobs": -1,
        "random_state": 42,
    }

    if params["bootstrap"]:
        params["max_samples"] = trial.suggest_float("max_samples", 0.5, 1.0)

    rf = RandomForestRegressor(**params)

    kf = KFold(n_splits=5, shuffle=True, random_state=42)
    fold_scores = []

    for train_idx, val_idx in kf.split(Xtr_np):
        X_fold_tr = Xtr_np[train_idx]
        X_fold_val = Xtr_np[val_idx]

        y_fold_tr = ytr_np[train_idx]
        y_fold_val = ytr_np[val_idx]

        yerr_fold_tr = yerr_tr_np[train_idx]
        yerr_fold_val = yerr_tr_np[val_idx]

        w_fold_tr = 1.0 / (yerr_fold_tr ** 2)

        rf.fit(X_fold_tr, y_fold_tr, sample_weight=w_fold_tr)
        y_fold_pred = rf.predict(X_fold_val)

        score = weighted_rmse(y_fold_val, y_fold_pred, yerr_fold_val)
        fold_scores.append(score)

    return np.mean(fold_scores)

# %%
study = optuna.create_study(direction="minimize")
study.optimize(objective, n_trials=50, show_progress_bar=True)

print("Best trial:", study.best_trial.number)
print("Best weighted CV RMSE:", study.best_value)
print("Best hyperparameters:")
print(study.best_params)
# Out:
# [I 2026-04-07 15:20:43,609] A new study created in memory with name: no-name-493eb003-9b73-4d95-ad3b-68cf2797e6e3
#   0%|          | 0/50 [00:00<?, ?it/s]
# [I 2026-04-07 15:20:44,955] Trial 0 finished with value: 0.21333173483817944 and parameters: {'n_estimators': 1000, 'max_depth': 4, 'min_samples_split': 19, 'min_samples_leaf': 6, 'max_features': None, 'bootstrap': False}. Best is trial 0 with value: 0.21333173483817944.
# [I 2026-04-07 15:20:45,375] Trial 1 finished with value: 0.20717801937424424 and parameters: {'n_estimators': 200, 'max_depth': 10, 'min_samples_split': 9, 'min_samples_leaf': 6, 'max_features': 'log2', 'bootstrap': True, 'max_samples': 0.6570492768698675}. Best is trial 1 with value: 0.20717801937424424.
# [I 2026-04-07 15:20:45,709] Trial 2 finished with value: 0.20265513324785317 and parameters: {'n_estimators': 200, 'max_depth': 26, 'min_samples_split': 18, 'min_samples_leaf': 8, 'max_features': 'log2', 'bootstrap': False}. Best is trial 2 with value: 0.20265513324785317.
# [I 2026-04-07 15:20:46,138] Trial 3 finished with value: 0.20417516827683682 and parameters: {'n_estimators': 200, 'max_depth': 18, 'min_samples_split': 11, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'bootstrap': True, 'max_samples': 0.5585794185388709}. Best is trial 2 with value: 0.20265513324785317.
# [I 2026-04-07 15:20:46,904] Trial 4 finished with value: 0.19821101354504056 and parameters: {'n_estimators': 400, 'max_depth': 11, 'min_samples_split': 7, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'bootstrap': True, 'max_samples': 0.8613817997389499}. Best is trial 4 with value: 0.19821101354504056.
# [I 2026-04-07 15:20:48,373] Trial 5 finished with value: 0.2275911430537767 and parameters: {'n_estimators': 800, 'max_depth': 3, 'min_samples_split': 9, 'min_samples_leaf': 10, 'max_features': 'sqrt', 'bootstrap': True, 'max_samples': 0.6247428407965645}. Best is trial 4 with value: 0.19821101354504056.
# [I 2026-04-07 15:20:50,221] Trial 6 finished with value: 0.20321510120601088 and parameters: {'n_estimators': 1000, 'max_depth': 20, 'min_samples_split': 10, 'min_samples_leaf': 6, 'max_features': 'log2', 'bootstrap': True, 'max_samples': 0.8392817696133805}. Best is trial 4 with value: 0.19821101354504056.
# [I 2026-04-07 15:20:52,559] Trial 7 finished with value: 0.21192961724259396 and parameters: {'n_estimators': 1300, 'max_depth': 10, 'min_samples_split': 8, 'min_samples_leaf': 9, 'max_features': 'sqrt', 'bootstrap': True, 'max_samples': 0.6863063935501068}. Best is trial 4 with value: 0.19821101354504056.
# [I 2026-04-07 15:20:53,787] Trial 8 finished with value: 0.1830351006762822 and parameters: {'n_estimators': 600, 'max_depth': 25, 'min_samples_split': 8, 'min_samples_leaf': 8, 'max_features': None, 'bootstrap': True, 'max_samples': 0.8780498426312093}. Best is trial 8 with value: 0.1830351006762822.
# [I 2026-04-07 15:20:55,163] Trial 9 finished with value: 0.2055885818023419 and parameters: {'n_estimators': 700, 'max_depth': 11, 'min_samples_split': 4, 'min_samples_leaf': 8, 'max_features': 'sqrt', 'bootstrap': True, 'max_samples': 0.9748148199900015}. Best is trial 8 with value: 0.1830351006762822.
# [I 2026-04-07 15:20:57,419] Trial 10 finished with value: 0.2534691476958028 and parameters: {'n_estimators': 1500, 'max_depth': 28, 'min_samples_split': 14, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': False}. Best is trial 8 with value: 0.1830351006762822.
# [I 2026-04-07 15:20:58,635] Trial 11 finished with value: 0.18222208601501408 and parameters: {'n_estimators': 500, 'max_depth': 24, 'min_samples_split': 3, 'min_samples_leaf': 3, 'max_features': None, 'bootstrap': True, 'max_samples': 0.852866308875742}. Best is trial 11 with value: 0.18222208601501408.
# [I 2026-04-07 15:20:59,953] Trial 12 finished with value: 0.18143053351165475 and parameters: {'n_estimators': 600, 'max_depth': 23, 'min_samples_split': 4, 'min_samples_leaf': 4, 'max_features': None, 'bootstrap': True, 'max_samples': 0.8260899949746565}. Best is trial 12 with value: 0.18143053351165475.
# [I 2026-04-07 15:21:00,997] Trial 13 finished with value: 0.1815366768616657 and parameters: {'n_estimators': 500, 'max_depth': 22, 'min_samples_split': 2, 'min_samples_leaf': 4, 'max_features': None, 'bootstrap': True, 'max_samples': 0.7731173836629289}. Best is trial 12 with value: 0.18143053351165475.
# [I 2026-04-07 15:21:01,613] Trial 14 finished with value: 0.24585544478489343 and parameters: {'n_estimators': 400, 'max_depth': 21, 'min_samples_split': 2, 'min_samples_leaf': 4, 'max_features': None, 'bootstrap': False}. Best is trial 12 with value: 0.18143053351165475.
# [I 2026-04-07 15:21:03,438] Trial 15 finished with value: 0.18250699175835394 and parameters: {'n_estimators': 900, 'max_depth': 30, 'min_samples_split': 5, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': True, 'max_samples': 0.7725695432978077}. Best is trial 12 with value: 0.18143053351165475.
# [I 2026-04-07 15:21:04,649] Trial 16 finished with value: 0.18156868950962302 and parameters: {'n_estimators': 600, 'max_depth': 16, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_features': None, 'bootstrap': True, 'max_samples': 0.7611480772248017}. Best is trial 12 with value: 0.18143053351165475.
# [I 2026-04-07 15:21:07,257] Trial 17 finished with value: 0.1824909396355586 and parameters: {'n_estimators': 1200, 'max_depth': 22, 'min_samples_split': 13, 'min_samples_leaf': 5, 'max_features': None, 'bootstrap': True, 'max_samples': 0.9746898325753572}. Best is trial 12 with value: 0.18143053351165475.
# [I 2026-04-07 15:21:07,899] Trial 18 finished with value: 0.25833579789453787 and parameters: {'n_estimators': 400, 'max_depth': 15, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': None, 'bootstrap': False}. Best is trial 12 with value: 0.18143053351165475.
# [I 2026-04-07 15:21:09,317] Trial 19 finished with value: 0.18104202624606514 and parameters: {'n_estimators': 700, 'max_depth': 18, 'min_samples_split': 6, 'min_samples_leaf': 5, 'max_features': None, 'bootstrap': True, 'max_samples': 0.7120054089595218}. Best is trial 19 with value: 0.18104202624606514.
# [I 2026-04-07 15:21:11,065] Trial 20 finished with value: 0.20267521630287955 and parameters: {'n_estimators': 800, 'max_depth': 14, 'min_samples_split': 6, 'min_samples_leaf': 5, 'max_features': 'log2', 'bootstrap': True, 'max_samples': 0.7206757519030714}. Best is trial 19 with value: 0.18104202624606514.
# [I 2026-04-07 15:21:12,425] Trial 21 finished with value: 0.18167906719399238 and parameters: {'n_estimators': 600, 'max_depth': 19, 'min_samples_split': 4, 'min_samples_leaf': 4, 'max_features': None, 'bootstrap': True, 'max_samples': 0.7938565194710283}. Best is trial 19 with value: 0.18104202624606514.
# [I 2026-04-07 15:21:13,939] Trial 22 finished with value: 0.18196916359710438 and parameters: {'n_estimators': 700, 'max_depth': 23, 'min_samples_split': 2, 'min_samples_leaf': 7, 'max_features': None, 'bootstrap': True, 'max_samples': 0.7153537663195737}. Best is trial 19 with value: 0.18104202624606514.
# [I 2026-04-07 15:21:15,056] Trial 23 finished with value: 0.18177258038496522 and parameters: {'n_estimators': 500, 'max_depth': 27, 'min_samples_split': 6, 'min_samples_leaf': 5, 'max_features': None, 'bootstrap': True, 'max_samples': 0.7969986106228026}. Best is trial 19 with value: 0.18104202624606514.
# [I 2026-04-07 15:21:16,919] Trial 24 finished with value: 0.1814660605077508 and parameters: {'n_estimators': 900, 'max_depth': 17, 'min_samples_split': 4, 'min_samples_leaf': 2, 'max_features': None, 'bootstrap': True, 'max_samples': 0.6301212820777755}. Best is trial 19 with value: 0.18104202624606514.
# [I 2026-04-07 15:21:18,996] Trial 25 finished with value: 0.18165282681307957 and parameters: {'n_estimators': 1000, 'max_depth': 18, 'min_samples_split': 12, 'min_samples_leaf': 2, 'max_features': None, 'bootstrap': True, 'max_samples': 0.5916542474642047}. Best is trial 19 with value: 0.18104202624606514.
# [I 2026-04-07 15:21:20,769] Trial 26 finished with value: 0.23189502900974368 and parameters: {'n_estimators': 1200, 'max_depth': 13, 'min_samples_split': 16, 'min_samples_leaf': 2, 'max_features': None, 'bootstrap': False}. Best is trial 19 with value: 0.18104202624606514.
# [I 2026-04-07 15:21:22,772] Trial 27 finished with value: 0.18146084035316998 and parameters: {'n_estimators': 900, 'max_depth': 6, 'min_samples_split': 4, 'min_samples_leaf': 3, 'max_features': None, 'bootstrap': True, 'max_samples': 0.511126045184133}. Best is trial 19 with value: 0.18104202624606514.
# [I 2026-04-07 15:21:24,185] Trial 28 finished with value: 0.20399981267370562 and parameters: {'n_estimators': 700, 'max_depth': 6, 'min_samples_split': 6, 'min_samples_leaf': 3, 'max_features': 'log2', 'bootstrap': True, 'max_samples': 0.5239429685166069}. Best is trial 19 with value: 0.18104202624606514.
# [I 2026-04-07 15:21:25,470] Trial 29 finished with value: 0.21151464046241758 and parameters: {'n_estimators': 900, 'max_depth': 5, 'min_samples_split': 7, 'min_samples_leaf': 7, 'max_features': None, 'bootstrap': False}. Best is trial 19 with value: 0.18104202624606514.
# [I 2026-04-07 15:21:27,895] Trial 30 finished with value: 0.18217907024509303 and parameters: {'n_estimators': 1100, 'max_depth': 8, 'min_samples_split': 4, 'min_samples_leaf': 5, 'max_features': None, 'bootstrap': True, 'max_samples': 0.9143681269839689}. Best is trial 19 with value: 0.18104202624606514.
# [I 2026-04-07 15:21:31,894] Trial 31 finished with value: 0.18131828132440073 and parameters: {'n_estimators': 900, 'max_depth': 17, 'min_samples_split': 4, 'min_samples_leaf': 2, 'max_features': None, 'bootstrap': True, 'max_samples': 0.5094094100245781}. Best is trial 19 with value: 0.18104202624606514.
# [I 2026-04-07 15:21:33,658] Trial 32 finished with value: 0.18131309848576863 and parameters: {'n_estimators': 800, 'max_depth': 20, 'min_samples_split': 3, 'min_samples_leaf': 4, 'max_features': None, 'bootstrap': True, 'max_samples': 0.5237208512193615}. Best is trial 19 with value: 0.18104202624606514.
# [I 2026-04-07 15:21:35,225] Trial 33 finished with value: 0.1824432125547558 and parameters: {'n_estimators': 800, 'max_depth': 20, 'min_samples_split': 3, 'min_samples_leaf': 6, 'max_features': None, 'bootstrap': True, 'max_samples': 0.559249859952961}. Best is trial 19 with value: 0.18104202624606514.
# [I 2026-04-07 15:21:36,542] Trial 34 finished with value: 0.21159681672532438 and parameters: {'n_estimators': 700, 'max_depth': 16, 'min_samples_split': 19, 'min_samples_leaf': 4, 'max_features': 'log2', 'bootstrap': True, 'max_samples': 0.5005659670754026}. Best is trial 19 with value: 0.18104202624606514.
# [I 2026-04-07 15:21:38,661] Trial 35 finished with value: 0.18184679676101673 and parameters: {'n_estimators': 1100, 'max_depth': 19, 'min_samples_split': 5, 'min_samples_leaf': 5, 'max_features': None, 'bootstrap': True, 'max_samples': 0.5494019449780593}. Best is trial 19 with value: 0.18104202624606514.
# [I 2026-04-07 15:21:39,290] Trial 36 finished with value: 0.19807266791628514 and parameters: {'n_estimators': 300, 'max_depth': 25, 'min_samples_split': 7, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'bootstrap': True, 'max_samples': 0.6121097972764037}. Best is trial 19 with value: 0.18104202624606514.
# [I 2026-04-07 15:21:40,471] Trial 37 finished with value: 0.21457591487390343 and parameters: {'n_estimators': 800, 'max_depth': 13, 'min_samples_split': 10, 'min_samples_leaf': 7, 'max_features': None, 'bootstrap': False}. Best is trial 19 with value: 0.18104202624606514.
# [I 2026-04-07 15:21:41,628] Trial 38 finished with value: 0.20621011779641388 and parameters: {'n_estimators': 600, 'max_depth': 18, 'min_samples_split': 3, 'min_samples_leaf': 6, 'max_features': 'log2', 'bootstrap': True, 'max_samples': 0.6488799320395071}. Best is trial 19 with value: 0.18104202624606514.
# [I 2026-04-07 15:21:43,726] Trial 39 finished with value: 0.19985581199339966 and parameters: {'n_estimators': 1000, 'max_depth': 21, 'min_samples_split': 8, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'bootstrap': True, 'max_samples': 0.6768098235369884}. Best is trial 19 with value: 0.18104202624606514.
# [I 2026-04-07 15:21:46,451] Trial 40 finished with value: 0.18131397201459573 and parameters: {'n_estimators': 700, 'max_depth': 17, 'min_samples_split': 6, 'min_samples_leaf': 4, 'max_features': None, 'bootstrap': True, 'max_samples': 0.5851775338402601}. Best is trial 19 with value: 0.18104202624606514.
# [I 2026-04-07 15:21:47,856] Trial 41 finished with value: 0.18131397201459573 and parameters: {'n_estimators': 700, 'max_depth': 17, 'min_samples_split': 6, 'min_samples_leaf': 4, 'max_features': None, 'bootstrap': True, 'max_samples': 0.5844620421762095}. Best is trial 19 with value: 0.18104202624606514.
# [I 2026-04-07 15:21:49,404] Trial 42 finished with value: 0.1812365399116696 and parameters: {'n_estimators': 800, 'max_depth': 17, 'min_samples_split': 9, 'min_samples_leaf': 3, 'max_features': None, 'bootstrap': True, 'max_samples': 0.5827579835947149}. Best is trial 19 with value: 0.18104202624606514.
# [I 2026-04-07 15:21:50,759] Trial 43 finished with value: 0.18129697661586133 and parameters: {'n_estimators': 700, 'max_depth': 15, 'min_samples_split': 9, 'min_samples_leaf': 4, 'max_features': None, 'bootstrap': True, 'max_samples': 0.5863233291106779}. Best is trial 19 with value: 0.18104202624606514.
# [I 2026-04-07 15:21:52,292] Trial 44 finished with value: 0.18132358911346472 and parameters: {'n_estimators': 800, 'max_depth': 12, 'min_samples_split': 10, 'min_samples_leaf': 3, 'max_features': None, 'bootstrap': True, 'max_samples': 0.5546585572426153}. Best is trial 19 with value: 0.18104202624606514.
# [I 2026-04-07 15:21:53,664] Trial 45 finished with value: 0.2044716710103765 and parameters: {'n_estimators': 700, 'max_depth': 15, 'min_samples_split': 9, 'min_samples_leaf': 5, 'max_features': 'sqrt', 'bootstrap': True, 'max_samples': 0.5901343907643255}. Best is trial 19 with value: 0.18104202624606514.
# [I 2026-04-07 15:21:55,234] Trial 46 finished with value: 0.18133835690411215 and parameters: {'n_estimators': 800, 'max_depth': 15, 'min_samples_split': 11, 'min_samples_leaf': 3, 'max_features': None, 'bootstrap': True, 'max_samples': 0.5366527635309799}. Best is trial 19 with value: 0.18104202624606514.
# [I 2026-04-07 15:21:56,236] Trial 47 finished with value: 0.18211055547429528 and parameters: {'n_estimators': 500, 'max_depth': 19, 'min_samples_split': 9, 'min_samples_leaf': 6, 'max_features': None, 'bootstrap': True, 'max_samples': 0.6403395486099451}. Best is trial 19 with value: 0.18104202624606514.
# [I 2026-04-07 15:21:58,397] Trial 48 finished with value: 0.24540853450709946 and parameters: {'n_estimators': 1500, 'max_depth': 10, 'min_samples_split': 8, 'min_samples_leaf': 4, 'max_features': None, 'bootstrap': False}. Best is trial 19 with value: 0.18104202624606514.
# [I 2026-04-07 15:21:59,691] Trial 49 finished with value: 0.18165438296527667 and parameters: {'n_estimators': 600, 'max_depth': 14, 'min_samples_split': 7, 'min_samples_leaf': 4, 'max_features': None, 'bootstrap': True, 'max_samples': 0.5746161650334946}. Best is trial 19 with value: 0.18104202624606514.
# Best trial: 19
# Best weighted CV RMSE: 0.18104202624606514
# Best hyperparameters:
# {'n_estimators': 700, 'max_depth': 18, 'min_samples_split': 6, 'min_samples_leaf': 5, 'max_features': None, 'bootstrap': True, 'max_samples': 0.7120054089595218}

# %%
best_params = study.best_params.copy()
best_params["n_jobs"] = -1
best_params["random_state"] = 42

rf = RandomForestRegressor(**best_params)

w = 1.0 / (yerr_tr.to_numpy() ** 2)

rf.fit(Xtr, ytr, sample_weight=w)
yhat = rf.predict(Xte)

# %%
test_weighted_rmse = weighted_rmse(yte.to_numpy(), yhat, yerr_te.to_numpy())
test_rmse = np.sqrt(mean_squared_error(yte, yhat))

print("Test weighted RMSE:", test_weighted_rmse)
print("Test RMSE:", test_rmse)
# Out:
# Test weighted RMSE: 0.16056460979117226
# Test RMSE: 0.1703137633515404

# %%
print("Feature Importances:")
feature_importances = pd.Series(rf.feature_importances_, index=feature_cols)
print(feature_importances.sort_values(ascending=False))
# Out:
# Feature Importances:
# ZTF_c                      0.667308
# ZTF_x1                     0.211386
# DESI_METADATA_Z            0.042872
# DESI_FASTSPEC_DN4000       0.017587
# DESI_FASTSPEC_g_minus_r    0.017554
# DESI_FASTSPEC_LOGMSTAR     0.012471
# DESI_FASTSPEC_SFR          0.011440
# DESI_FASTSPEC_AGE          0.011235
# DESI_FASTSPEC_VDISP        0.008146
# dtype: float64

# %%
plt.figure(figsize=(6, 6))
plt.scatter(yte, yhat, alpha=0.7)
plt.xlabel("True residuals")
plt.ylabel("Predicted residuals")
plt.axline((0, 0), slope=1, linestyle="--")

plt.xlim(-1, 1)
plt.ylim(-1, 1)

plt.tight_layout()
plt.show()

# %%
from scipy.stats import binned_statistic

nbins = 10
point_kwargs = dict(alpha=0.2, s=50, color="grey", zorder=3)

def scatter_with_errors(ax, xcol, nbins=None, xerr_col=None, xerr_direct_col=None):
    """
    Plots scatter cloud with y-error bars, optional x-error bars, 
    and binned means with spread error bars.
    
    xerr_col      — column name of INVERSE VARIANCE (e.g. DESI_FASTSPEC_DN4000_IVAR)
    xerr_direct_col — column name of direct error (e.g. ZTF_x1_err)
    """
    x = df[xcol]
    y = df["residuals"]
    yerr = df["ZTF_sigma_mu"]

    # Optional horizontal error bars
    if xerr_col is not None:
        xerr = 1.0 / np.sqrt(df[xerr_col])
    elif xerr_direct_col is not None:
        xerr = df[xerr_direct_col]
    else:
        xerr = None

    # --- scatter cloud ---
    ax.scatter(x, y, **point_kwargs)

    # --- individual error bars ---
    ax.errorbar(
        x, y, yerr=yerr, xerr=xerr,
        fmt="none",
        ecolor="black",
        elinewidth=0.5,
        alpha=0.25,
        zorder=2,
    )

    # horizontal reference
    ax.axhline(0, linestyle="--", color="orange")

    # --- BINNING WITH ERROR PROPAGATION ---
    _, bin_edges, binnumber = binned_statistic(x, x, statistic="count", bins=nbins)
    bin_centers = 0.5 * (bin_edges[:-1] + bin_edges[1:])

    binned_y = []
    binned_yerr = []

    for i in range(1, len(bin_edges)):
        in_bin = binnumber == i

        if np.sum(in_bin) == 0:
            binned_y.append(np.nan)
            binned_yerr.append(np.nan)
            continue

        y_bin = y[in_bin]
        y_mean = np.mean(y_bin)
        err_spread = np.std(y_bin, ddof=1)

        binned_y.append(y_mean)
        binned_yerr.append(err_spread)

    binned_y = np.array(binned_y)
    binned_yerr = np.array(binned_yerr)
    ok = np.isfinite(binned_y) & np.isfinite(binned_yerr)

    ax.errorbar(
        bin_centers[ok],
        binned_y[ok],
        yerr=binned_yerr[ok],
        fmt="o",
        color="blue",
        markersize=7,
        capsize=3,
        zorder=5,
    )

# %%
fig, axes = plt.subplots(3, 3, figsize=(16, 12), sharey=True)
axes = axes.flatten()

plot_features = feature_cols
plot_labels = [
    r"$\log_{10}(M_\star / M_{\odot})$",
    r"${\rm SFR}\ (M_{\odot}/yr)$",
    r"$\sigma_v\ (km/s)$",
    r"$D_n4000$",
    r"$g - r\ (mag)$",
    r"${\rm Age}\ (Gyr)$",
    r"$z_{\rm DESI}$",
    r"$x_1$",
    r"$c$",
]

for i, (feat, label) in enumerate(zip(plot_features, plot_labels)):
    ax = axes[i]
    ax.errorbar(
        Xtr[feat], ytr,
        yerr=yerr_tr,
        fmt="o", markersize=4, alpha=0.25,
        color="gray", ecolor="gray", elinewidth=0.5, capsize=0,
        label="Training data", zorder=1,
    )
    ax.scatter(
        Xte[feat], yhat,
        alpha=0.6, s=16, color="orange",
        label="Predictions", zorder=2,
    )
    ax.set_xlabel(label)
    if i % 3 == 0:
        ax.set_ylabel(r"$\Delta \mu$")
    ax.axhline(0, linestyle="--", color="red", alpha=0.3)

axes[0].legend(fontsize=8)
fig.suptitle("Training Data vs RF Predictions", fontsize=14, y=1.01)
fig.tight_layout()
plt.show()

# %%
bins = np.linspace(-1.5, 1.5, 30)

plt.figure(figsize=(8, 5))
plt.hist(yte, bins=bins, alpha=0.3, color="grey", label="True residuals (test set)")
plt.hist(yhat, bins=bins, alpha=0.5, color="orange", label="RF predictions (test set)")
plt.xlabel(r"$\Delta \mu$")
plt.ylabel("Count")
plt.legend()
plt.tight_layout()
plt.show()

# %%
from sklearn.inspection import partial_dependence

# Map column names to pretty LaTeX labels
FEATURE_LABELS = {
    "DESI_FASTSPEC_LOGMSTAR":    r"$\log_{10}(M_\star / M_{\odot})$",
    "DESI_FASTSPEC_SFR":         r"${\rm SFR}\ (M_{\odot}/yr)$",
    "DESI_FASTSPEC_VDISP":       r"$\sigma_v\ (km/s)$",
    "DESI_FASTSPEC_DN4000":      r"$D_n4000$",
    "DESI_FASTSPEC_g_minus_r":   r"$g - r\ (mag)$",
    "DESI_FASTSPEC_AGE":         r"${\rm Age}\ (Gyr)$",
    "DESI_METADATA_Z":           r"$z_{\rm DESI}$",
    "ZTF_x1":                    r"$x_1$",
    "ZTF_c":                     r"$c$",
}

# Map features to their x-axis error columns
FEATURE_XERR = {
    "DESI_FASTSPEC_VDISP":  {"xerr_col": "DESI_FASTSPEC_VDISP_IVAR"},
    "DESI_FASTSPEC_DN4000": {"xerr_col": "DESI_FASTSPEC_DN4000_IVAR"},
    "ZTF_x1":               {"xerr_direct_col": "ZTF_x1_err"},
    "ZTF_c":                {"xerr_direct_col": "ZTF_c_err"},
}

def plot_pd_panel(ax, feature, rf, X, feature_cols, nbins=10, method="recursion"):
    X_pd = X[feature_cols]

    res = partial_dependence(
        estimator=rf,
        X=X_pd,
        features=[feature],
        method=method,
        percentiles=(0.00, 1.00),
    )
    x_grid = res["grid_values"][0]
    y_grid = res["average"][0]

    # PD curve
    ax.scatter(x_grid, y_grid, alpha=0.6, s=30, color="orange",
               label="PD (marginalized)", zorder=4)

    # Raw + binned overlay — pass x-axis errors if available
    global point_kwargs
    old_kwargs = point_kwargs.copy()
    point_kwargs.update({"label": "Raw Data"})
    xerr_kwargs = FEATURE_XERR.get(feature, {})
    scatter_with_errors(ax, feature, nbins=nbins, **xerr_kwargs)
    point_kwargs.clear()
    point_kwargs.update(old_kwargs)

    ax.errorbar([], [], fmt="o", color="blue", markersize=4, label="Binned raw data")

    # Axis labels
    ax.set_xlabel(FEATURE_LABELS.get(feature, feature))
    ax.set_ylabel(r"$\Delta \mu$")


fig, axes = plt.subplots(3, 3, figsize=(16, 12), sharey=True)

plot_pd_panel(axes[0, 0], "DESI_FASTSPEC_LOGMSTAR",    rf, X, feature_cols, nbins=nbins)
plot_pd_panel(axes[0, 1], "DESI_FASTSPEC_SFR",          rf, X, feature_cols, nbins=nbins)
plot_pd_panel(axes[0, 2], "DESI_FASTSPEC_VDISP",        rf, X, feature_cols, nbins=nbins)

plot_pd_panel(axes[1, 0], "DESI_FASTSPEC_DN4000",       rf, X, feature_cols, nbins=nbins)
plot_pd_panel(axes[1, 1], "DESI_FASTSPEC_g_minus_r",    rf, X, feature_cols, nbins=nbins)
plot_pd_panel(axes[1, 2], "DESI_FASTSPEC_AGE",          rf, X, feature_cols, nbins=nbins)

plot_pd_panel(axes[2, 0], "DESI_METADATA_Z",            rf, X, feature_cols, nbins=20)
axes[2, 0].set_xlim(0, 0.12)
plot_pd_panel(axes[2, 1], "ZTF_x1",                     rf, X, feature_cols, nbins=nbins)
plot_pd_panel(axes[2, 2], "ZTF_c",                      rf, X, feature_cols, nbins=nbins)

handles, labels = axes[0, 0].get_legend_handles_labels()
fig.legend(handles, labels, loc="upper center", ncol=3, frameon=False)

fig.suptitle("Partial Dependence Plots", fontsize=14, y=1.02)
plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()
