# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import optuna

from sklearn.model_selection import train_test_split, KFold
from sklearn.model_selection import cross_val_predict
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
import optuna.visualization as vis

import os

from astropy.cosmology import FlatLambdaCDM

# %%
df = pd.read_csv("data/ZTF_DESI_matched_lc_cuts_z_cuts_hostprop_cleaned_chi2_only.csv")

print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 521 entries, 0 to 520
# Data columns (total 69 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   ZTF_Unnamed: 0                    521 non-null    float64
#  1   ztfname                           521 non-null    object
#  2   ZTF_redshift                      521 non-null    float64
#  3   ZTF_redshift_err                  521 non-null    float64
#  4   ZTF_source                        521 non-null    object
#  5   ZTF_t0                            521 non-null    float64
#  6   ZTF_x0                            521 non-null    float64
#  7   ZTF_x1                            521 non-null    float64
#  8   ZTF_c                             521 non-null    float64
#  9   ZTF_t0_err                        521 non-null    float64
#  10  ZTF_x0_err                        521 non-null    float64
#  11  ZTF_x1_err                        521 non-null    float64
#  12  ZTF_c_err                         521 non-null    float64
#  13  ZTF_cov_t0_x0                     521 non-null    float64
#  14  ZTF_cov_t0_x1                     521 non-null    float64
#  15  ZTF_cov_t0_c                      521 non-null    float64
#  16  ZTF_cov_x0_x1                     521 non-null    float64
#  17  ZTF_cov_x0_c                      521 non-null    float64
#  18  ZTF_cov_x1_c                      521 non-null    float64
#  19  ZTF_mwebv                         521 non-null    float64
#  20  ZTF_mwr_v                         521 non-null    float64
#  21  ZTF_mwebv_err                     521 non-null    float64
#  22  ZTF_fitprob                       521 non-null    float64
#  23  ZTF_ra                            521 non-null    float64
#  24  ZTF_dec                           521 non-null    float64
#  25  ZTF_sn_type                       521 non-null    object
#  26  ZTF_sub_type                      438 non-null    object
#  27  ZTF_lccoverage_flag               521 non-null    float64
#  28  ZTF_fitquality_flag               521 non-null    float64
#  29  ZTF_iau_name                      507 non-null    object
#  30  ZTF_frac_fitted                   521 non-null    float64
#  31  ZTF_ra_host_global                521 non-null    float64
#  32  ZTF_dec_host_global               521 non-null    float64
#  33  ZTF_mass_global                   519 non-null    float64
#  34  ZTF_mass_err_global               519 non-null    float64
#  35  ZTF_restframe_gz_global           519 non-null    float64
#  36  ZTF_restframe_gz_err_global       519 non-null    float64
#  37  ZTF_d_dlr_global                  521 non-null    float64
#  38  ZTF_mass_local                    515 non-null    float64
#  39  ZTF_mass_err_local                519 non-null    float64
#  40  ZTF_restframe_gz_local            515 non-null    float64
#  41  ZTF_restframe_gz_err_local        515 non-null    float64
#  42  ZTF_DESI_METADATA_ang_sep_arcsec  521 non-null    float64
#  43  DESI_METADATA_TARGETID            521 non-null    float64
#  44  DESI_METADATA_LS_ID               521 non-null    float64
#  45  DESI_METADATA_SPECTYPE            521 non-null    object
#  46  DESI_METADATA_RA                  521 non-null    float64
#  47  DESI_METADATA_DEC                 521 non-null    float64
#  48  DESI_METADATA_DESI_TARGET         521 non-null    float64
#  49  DESI_METADATA_Z                   521 non-null    float64
#  50  DESI_METADATA_ZWARN               521 non-null    float64
#  51  DESI_METADATA_PROGRAM             521 non-null    object
#  52  DESI_METADATA_SURVEY              521 non-null    object
#  53  DESI_FASTSPEC_TARGETID            521 non-null    float64
#  54  DESI_FASTSPEC_HEALPIX             521 non-null    float64
#  55  DESI_FASTSPEC_VDISP               521 non-null    float64
#  56  DESI_FASTSPEC_VDISP_IVAR          521 non-null    float64
#  57  DESI_FASTSPEC_LOGMSTAR            521 non-null    float64
#  58  DESI_FASTSPEC_SFR                 521 non-null    float64
#  59  DESI_FASTSPEC_AGE                 521 non-null    float64
#  60  DESI_FASTSPEC_DN4000              521 non-null    float64
#  61  DESI_FASTSPEC_DN4000_IVAR         521 non-null    float64
#  62  DESI_FASTSPEC_ABSMAG01_SDSS_G     521 non-null    float64
#  63  DESI_FASTSPEC_ZZSUN               521 non-null    float64
#  64  DESI_FASTSPEC_ABSMAG01_SDSS_R     521 non-null    float64
#  65  DESI_FASTSPEC_g_minus_r           521 non-null    float64
#  66  ZTF_mu_obs                        521 non-null    float64
#  67  ZTF_sigma_mu                      521 non-null    float64
#  68  residuals                         521 non-null    float64
# dtypes: float64(61), object(8)
# memory usage: 281.0+ KB
# None

# %%
feature_cols = [
    "DESI_FASTSPEC_LOGMSTAR",
    "DESI_FASTSPEC_SFR",
    "DESI_FASTSPEC_VDISP",
    "DESI_FASTSPEC_DN4000",
    "DESI_FASTSPEC_g_minus_r",
    "DESI_FASTSPEC_AGE",
    "DESI_METADATA_Z"
]

target_col = "residuals"

yerr_all = df["ZTF_sigma_mu"]

X = df[feature_cols]
y = df[target_col]

# %%
# No train/test split — we use 5-fold CV on the full dataset
X_np = X.to_numpy()
y_np = y.to_numpy()

# %% [markdown]
# # Defining Optuna Study Objective #
#
# Here we have to set a "reasonable" range of hyperparameters to tune for the random forest. This is b/c optuna doesn't just start from scratch.
#
#
# The full list of Random Forest Hyperparameters can be found here: https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestClassifier.html
#
# The parameters I choose to vary:
#
# n_estimatorsint, default=100 The number of trees in the forest. varying from defualt to 1500 in steps of 100.
# max_depthint, default=None The maximum depth of the tree. If None, then nodes are expanded until all leaves are pure or until all leaves contain less than min_samples_split samples. Ended up varying depth to some max amount. Did some trial and error to see what range is good. If the search settled on some smaller number, inceased to larger number and then dialed back so as not to waste computation space.
#
# min_samples_splitint or float, default=2 The minimum number of samples required to split an internal node: If int, then consider min_samples_split as the minimum number. If float, then min_samples_split is a fraction and ceil(min_samples_split * n_samples) are the minimum number of samples for each split. Started at the default and incrased to a larger number.
#
# min_samples_leafint or float, default=1
# The minimum number of samples required to be at a leaf node. A split point at any depth will only be considered if it leaves at least min_samples_leaf training samples in each of the left and right branches. This may have the effect of smoothing the model, especially in regression.
#
# If int, then consider min_samples_leaf as the minimum number. If float, then min_samples_leaf is a fraction and ceil(min_samples_leaf * n_samples) are the minimum number of samples for each node.
#
# ## `min_samples_leaf` — Controlling Leaf Bucket Size
#
# `min_samples_leaf` sets the minimum number of SNe Ia allowed in any
# final leaf node (bucket) of a decision tree.
#
# - `min_samples_leaf=1`: A leaf can contain a single SN. That SN's
#   Δμ becomes the prediction for anything landing in that bucket.
#   This is essentially memorizing individual data points.
#
# - `min_samples_leaf=10`: Every leaf must contain at least 10 SNe.
#   The prediction is the average Δμ of those 10 SNe — a much
#   smoother, more stable estimate that is harder to overfit.
#
# Our Optuna search explores the range 1–10, letting the optimization
# decide how granular the leaf buckets should be.
#
# ### Interaction with `max_depth`
#
# These two hyperparameters control the same thing — tree complexity —
# from opposite directions:
#
# - `max_depth` limits complexity **from the top**: how many sequential
#   splits a tree is allowed to make.
# - `min_samples_leaf` limits complexity **from the bottom**: how small
#   the resulting buckets can get.
#
# With our best-fit `max_depth=3` (~8 leaf nodes for 521 SNe), even
# `min_samples_leaf=1` is not dangerous because the tree is too shallow
# to isolate individual SNe. However, if Optuna had selected
# `max_depth=30`, then `min_samples_leaf` would serve as the safety
# net preventing the tree from creating tiny, noise-dominated buckets.
#
#
# # Max Features #
#
# "max_features": trial.suggest_categorical("max_features", ["sqrt", "log2", None]). Wnate dto play around what is better.
#
#
#
# The parameters I choose to keep default:
#
# criterion{“gini”, “entropy”, “log_loss”}, default=”gini”- b/c its the default method of criterion evaluation (See. 8.1.2 of "An Introductin to Statistical Learning")

# %%
def objective(trial):

    # Parameters we suggest to optimize and caps on their ranges.
    # Optuna will automatically sample values for these parameters within the specified ranges.
    # It will prune unpromising trials based on intermediate results. So not everything 
    params = {
        "n_estimators": trial.suggest_int("n_estimators", 100, 1500, step=100),
        "max_depth": trial.suggest_int("max_depth", 3, 30),
        "min_samples_split": trial.suggest_int("min_samples_split", 2, 20),
        "min_samples_leaf": trial.suggest_int("min_samples_leaf", 1, 20),
        "max_features": trial.suggest_categorical("max_features", ["sqrt", "log2", None]),
        "bootstrap": trial.suggest_categorical("bootstrap", [True, False]),
        "n_jobs": -1,
        "random_state": 42,
    }

    # only runs the following code if boostram is set to True.
    if params["bootstrap"]:
        params["max_samples"] = trial.suggest_float("max_samples", 0.5, 1.0)

    ## ** is python dictionary unpacking syntax
    # which allows us to pass the parameters as keyword arguments to the RandomForestRegressor constructor.
    rf = RandomForestRegressor(**params)

    # Creates a splitter object that will divide training data into 5 equal chunks. 
    # Shuffle True means that the data will be randomly shuffled before splitting
    # (ensures that each fold is representative of the overall dataset.). 
    kf = KFold(n_splits=5, shuffle=True, random_state=42)
    fold_scores = [] # for MSE scores of each fold

    # We had previously split the data into train/test (521/104)
    # 5-fold cross validation on the full 521 SNe.
    # Each fold: ~417 train and ~104 validation.
    for train_idx, val_idx in kf.split(X_np):
        X_fold_tr = X_np[train_idx]
        X_fold_val = X_np[val_idx]

        y_fold_tr = y_np[train_idx]
        y_fold_val = y_np[val_idx]

        rf.fit(X_fold_tr, y_fold_tr)
        y_fold_pred = rf.predict(X_fold_val)

        score = mean_squared_error(y_fold_val, y_fold_pred)
        fold_scores.append(score)

    # The Value Optuna is Minnimizing.
    return np.mean(fold_scores)

# %%
study_name = "optuna_runs_info/rf_prediction_corrected_tripp_host_chi2_only"

db_path = f"{study_name}.db"
if os.path.exists(db_path):
    os.remove(db_path)

study = optuna.create_study(direction="minimize", storage=f"sqlite:///{db_path}", study_name=study_name)
study.optimize(objective, n_trials=75, show_progress_bar=True) # 75 different hyperparameter combinations will be tried.

print("Best trial:", study.best_trial.number)
print("Best MSE:", study.best_value)
print("Best hyperparameters:")
print(study.best_params)
# Out:
# [I 2026-04-14 16:04:46,397] A new study created in RDB with name: optuna_runs_info/rf_prediction_corrected_tripp_host_chi2_only
#   0%|          | 0/75 [00:00<?, ?it/s]
# [I 2026-04-14 16:04:49,028] Trial 0 finished with value: 0.032448548543883106 and parameters: {'n_estimators': 1400, 'max_depth': 7, 'min_samples_split': 18, 'min_samples_leaf': 10, 'max_features': None, 'bootstrap': True, 'max_samples': 0.511327736473109}. Best is trial 0 with value: 0.032448548543883106.
# [I 2026-04-14 16:04:49,988] Trial 1 finished with value: 0.03202789728702618 and parameters: {'n_estimators': 500, 'max_depth': 12, 'min_samples_split': 5, 'min_samples_leaf': 15, 'max_features': 'log2', 'bootstrap': True, 'max_samples': 0.6145695456158261}. Best is trial 1 with value: 0.03202789728702618.
# [I 2026-04-14 16:04:50,785] Trial 2 finished with value: 0.03198129885839591 and parameters: {'n_estimators': 400, 'max_depth': 13, 'min_samples_split': 15, 'min_samples_leaf': 16, 'max_features': 'log2', 'bootstrap': True, 'max_samples': 0.6566132273245134}. Best is trial 2 with value: 0.03198129885839591.
# [I 2026-04-14 16:04:53,535] Trial 3 finished with value: 0.03292955784618342 and parameters: {'n_estimators': 1500, 'max_depth': 8, 'min_samples_split': 17, 'min_samples_leaf': 7, 'max_features': 'log2', 'bootstrap': True, 'max_samples': 0.9543553202347255}. Best is trial 2 with value: 0.03198129885839591.
# [I 2026-04-14 16:04:55,209] Trial 4 finished with value: 0.038391179706641174 and parameters: {'n_estimators': 1300, 'max_depth': 26, 'min_samples_split': 17, 'min_samples_leaf': 14, 'max_features': None, 'bootstrap': False}. Best is trial 2 with value: 0.03198129885839591.
# [I 2026-04-14 16:04:57,241] Trial 5 finished with value: 0.03193466984984787 and parameters: {'n_estimators': 1100, 'max_depth': 22, 'min_samples_split': 15, 'min_samples_leaf': 16, 'max_features': 'log2', 'bootstrap': True, 'max_samples': 0.5112728498778444}. Best is trial 5 with value: 0.03193466984984787.
# [I 2026-04-14 16:04:58,692] Trial 6 finished with value: 0.03213210142187849 and parameters: {'n_estimators': 800, 'max_depth': 19, 'min_samples_split': 4, 'min_samples_leaf': 14, 'max_features': 'sqrt', 'bootstrap': True, 'max_samples': 0.6902032333347198}. Best is trial 5 with value: 0.03193466984984787.
# [I 2026-04-14 16:04:59,454] Trial 7 finished with value: 0.032013637645011896 and parameters: {'n_estimators': 400, 'max_depth': 24, 'min_samples_split': 4, 'min_samples_leaf': 20, 'max_features': 'log2', 'bootstrap': True, 'max_samples': 0.9728320333820697}. Best is trial 5 with value: 0.03193466984984787.
# [I 2026-04-14 16:05:02,032] Trial 8 finished with value: 0.033566606054088344 and parameters: {'n_estimators': 1400, 'max_depth': 15, 'min_samples_split': 13, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'bootstrap': True, 'max_samples': 0.8057175869060883}. Best is trial 5 with value: 0.03193466984984787.
# [I 2026-04-14 16:05:02,695] Trial 9 finished with value: 0.03309447861445689 and parameters: {'n_estimators': 500, 'max_depth': 6, 'min_samples_split': 19, 'min_samples_leaf': 13, 'max_features': 'sqrt', 'bootstrap': False}. Best is trial 5 with value: 0.03193466984984787.
# [I 2026-04-14 16:05:03,932] Trial 10 finished with value: 0.03261188003055784 and parameters: {'n_estimators': 1000, 'max_depth': 30, 'min_samples_split': 9, 'min_samples_leaf': 19, 'max_features': 'log2', 'bootstrap': False}. Best is trial 5 with value: 0.03193466984984787.
# [I 2026-04-14 16:05:04,250] Trial 11 finished with value: 0.03188905515521126 and parameters: {'n_estimators': 100, 'max_depth': 20, 'min_samples_split': 13, 'min_samples_leaf': 18, 'max_features': 'log2', 'bootstrap': True, 'max_samples': 0.5035410187799587}. Best is trial 11 with value: 0.03188905515521126.
# [I 2026-04-14 16:05:06,115] Trial 12 finished with value: 0.03193534699256368 and parameters: {'n_estimators': 1000, 'max_depth': 21, 'min_samples_split': 10, 'min_samples_leaf': 17, 'max_features': 'log2', 'bootstrap': True, 'max_samples': 0.5152056857372809}. Best is trial 11 with value: 0.03188905515521126.
# [I 2026-04-14 16:05:06,561] Trial 13 finished with value: 0.03223090938449294 and parameters: {'n_estimators': 200, 'max_depth': 19, 'min_samples_split': 13, 'min_samples_leaf': 10, 'max_features': 'log2', 'bootstrap': True, 'max_samples': 0.5754085721981972}. Best is trial 11 with value: 0.03188905515521126.
# [I 2026-04-14 16:05:06,815] Trial 14 finished with value: 0.0328821156310231 and parameters: {'n_estimators': 100, 'max_depth': 25, 'min_samples_split': 8, 'min_samples_leaf': 18, 'max_features': 'log2', 'bootstrap': False}. Best is trial 11 with value: 0.03188905515521126.
# [I 2026-04-14 16:05:08,380] Trial 15 finished with value: 0.03376435226857398 and parameters: {'n_estimators': 800, 'max_depth': 29, 'min_samples_split': 12, 'min_samples_leaf': 7, 'max_features': None, 'bootstrap': True, 'max_samples': 0.8108881453130321}. Best is trial 11 with value: 0.03188905515521126.
# [I 2026-04-14 16:05:10,360] Trial 16 finished with value: 0.03212305813446473 and parameters: {'n_estimators': 1100, 'max_depth': 22, 'min_samples_split': 15, 'min_samples_leaf': 12, 'max_features': 'log2', 'bootstrap': True, 'max_samples': 0.5785821490540831}. Best is trial 11 with value: 0.03188905515521126.
# [I 2026-04-14 16:05:11,688] Trial 17 finished with value: 0.03191552876313845 and parameters: {'n_estimators': 700, 'max_depth': 16, 'min_samples_split': 7, 'min_samples_leaf': 20, 'max_features': 'log2', 'bootstrap': True, 'max_samples': 0.709882816292883}. Best is trial 11 with value: 0.03188905515521126.
# [I 2026-04-14 16:05:12,484] Trial 18 finished with value: 0.0325668860356053 and parameters: {'n_estimators': 600, 'max_depth': 17, 'min_samples_split': 7, 'min_samples_leaf': 20, 'max_features': 'sqrt', 'bootstrap': False}. Best is trial 11 with value: 0.03188905515521126.
# [I 2026-04-14 16:05:12,964] Trial 19 finished with value: 0.03506438825261445 and parameters: {'n_estimators': 200, 'max_depth': 11, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': True, 'max_samples': 0.7535499230819541}. Best is trial 11 with value: 0.03188905515521126.
# [I 2026-04-14 16:05:14,302] Trial 20 finished with value: 0.03211177932965548 and parameters: {'n_estimators': 700, 'max_depth': 15, 'min_samples_split': 6, 'min_samples_leaf': 18, 'max_features': 'log2', 'bootstrap': True, 'max_samples': 0.8513095964264907}. Best is trial 11 with value: 0.03188905515521126.
# [I 2026-04-14 16:05:16,497] Trial 21 finished with value: 0.03192220382185697 and parameters: {'n_estimators': 1200, 'max_depth': 18, 'min_samples_split': 15, 'min_samples_leaf': 17, 'max_features': 'log2', 'bootstrap': True, 'max_samples': 0.5116009307203508}. Best is trial 11 with value: 0.03188905515521126.
# [I 2026-04-14 16:05:18,711] Trial 22 finished with value: 0.03196020557430109 and parameters: {'n_estimators': 1200, 'max_depth': 18, 'min_samples_split': 11, 'min_samples_leaf': 20, 'max_features': 'log2', 'bootstrap': True, 'max_samples': 0.693743799292052}. Best is trial 11 with value: 0.03188905515521126.
# [I 2026-04-14 16:05:20,373] Trial 23 finished with value: 0.03190612667557209 and parameters: {'n_estimators': 900, 'max_depth': 3, 'min_samples_split': 20, 'min_samples_leaf': 18, 'max_features': 'log2', 'bootstrap': True, 'max_samples': 0.5767729147194569}. Best is trial 11 with value: 0.03188905515521126.
# [I 2026-04-14 16:05:22,045] Trial 24 finished with value: 0.031887631921167274 and parameters: {'n_estimators': 900, 'max_depth': 3, 'min_samples_split': 20, 'min_samples_leaf': 18, 'max_features': 'log2', 'bootstrap': True, 'max_samples': 0.5881336012307266}. Best is trial 24 with value: 0.031887631921167274.
# [I 2026-04-14 16:05:23,949] Trial 25 finished with value: 0.03198787176555513 and parameters: {'n_estimators': 900, 'max_depth': 3, 'min_samples_split': 20, 'min_samples_leaf': 8, 'max_features': 'log2', 'bootstrap': True, 'max_samples': 0.5866252146699843}. Best is trial 24 with value: 0.031887631921167274.
# [I 2026-04-14 16:05:25,089] Trial 26 finished with value: 0.03286050640496354 and parameters: {'n_estimators': 900, 'max_depth': 3, 'min_samples_split': 20, 'min_samples_leaf': 4, 'max_features': 'log2', 'bootstrap': False}. Best is trial 24 with value: 0.031887631921167274.
# [I 2026-04-14 16:05:26,661] Trial 27 finished with value: 0.03212979930884326 and parameters: {'n_estimators': 800, 'max_depth': 9, 'min_samples_split': 18, 'min_samples_leaf': 12, 'max_features': 'log2', 'bootstrap': True, 'max_samples': 0.6360965061160985}. Best is trial 24 with value: 0.031887631921167274.
# [I 2026-04-14 16:05:28,555] Trial 28 finished with value: 0.03195473191318126 and parameters: {'n_estimators': 1000, 'max_depth': 5, 'min_samples_split': 17, 'min_samples_leaf': 18, 'max_features': 'sqrt', 'bootstrap': True, 'max_samples': 0.5632737725597649}. Best is trial 24 with value: 0.031887631921167274.
# [I 2026-04-14 16:05:29,759] Trial 29 finished with value: 0.03205194834603356 and parameters: {'n_estimators': 600, 'max_depth': 10, 'min_samples_split': 19, 'min_samples_leaf': 16, 'max_features': None, 'bootstrap': True, 'max_samples': 0.5579553370033093}. Best is trial 24 with value: 0.031887631921167274.
# [I 2026-04-14 16:05:30,389] Trial 30 finished with value: 0.03228122155749548 and parameters: {'n_estimators': 300, 'max_depth': 4, 'min_samples_split': 18, 'min_samples_leaf': 11, 'max_features': None, 'bootstrap': True, 'max_samples': 0.6255887966814699}. Best is trial 24 with value: 0.031887631921167274.
# [I 2026-04-14 16:05:31,702] Trial 31 finished with value: 0.03193046930941945 and parameters: {'n_estimators': 700, 'max_depth': 7, 'min_samples_split': 9, 'min_samples_leaf': 19, 'max_features': 'log2', 'bootstrap': True, 'max_samples': 0.6862951629557837}. Best is trial 24 with value: 0.031887631921167274.
# [I 2026-04-14 16:05:33,347] Trial 32 finished with value: 0.03208889561632057 and parameters: {'n_estimators': 900, 'max_depth': 14, 'min_samples_split': 20, 'min_samples_leaf': 15, 'max_features': 'log2', 'bootstrap': True, 'max_samples': 0.7374198558167868}. Best is trial 24 with value: 0.031887631921167274.
# [I 2026-04-14 16:05:34,670] Trial 33 finished with value: 0.031914990106813805 and parameters: {'n_estimators': 700, 'max_depth': 6, 'min_samples_split': 2, 'min_samples_leaf': 19, 'max_features': 'log2', 'bootstrap': True, 'max_samples': 0.5519189336325088}. Best is trial 24 with value: 0.031887631921167274.
# [I 2026-04-14 16:05:34,977] Trial 34 finished with value: 0.03191512369963411 and parameters: {'n_estimators': 100, 'max_depth': 6, 'min_samples_split': 16, 'min_samples_leaf': 17, 'max_features': 'log2', 'bootstrap': True, 'max_samples': 0.5435596664664665}. Best is trial 24 with value: 0.031887631921167274.
# [I 2026-04-14 16:05:35,773] Trial 35 finished with value: 0.031932679073098165 and parameters: {'n_estimators': 400, 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 15, 'max_features': 'log2', 'bootstrap': True, 'max_samples': 0.5490110926188785}. Best is trial 24 with value: 0.031887631921167274.
# [I 2026-04-14 16:05:36,921] Trial 36 finished with value: 0.031865629539903455 and parameters: {'n_estimators': 600, 'max_depth': 5, 'min_samples_split': 13, 'min_samples_leaf': 19, 'max_features': 'log2', 'bootstrap': True, 'max_samples': 0.6100862670774182}. Best is trial 36 with value: 0.031865629539903455.
# [I 2026-04-14 16:05:38,059] Trial 37 finished with value: 0.03190291515943587 and parameters: {'n_estimators': 600, 'max_depth': 3, 'min_samples_split': 13, 'min_samples_leaf': 16, 'max_features': 'log2', 'bootstrap': True, 'max_samples': 0.6053573521548855}. Best is trial 36 with value: 0.031865629539903455.
# [I 2026-04-14 16:05:38,748] Trial 38 finished with value: 0.0327705594954529 and parameters: {'n_estimators': 500, 'max_depth': 5, 'min_samples_split': 13, 'min_samples_leaf': 16, 'max_features': 'log2', 'bootstrap': False}. Best is trial 36 with value: 0.031865629539903455.
# [I 2026-04-14 16:05:40,041] Trial 39 finished with value: 0.03202912261445221 and parameters: {'n_estimators': 600, 'max_depth': 12, 'min_samples_split': 14, 'min_samples_leaf': 14, 'max_features': 'log2', 'bootstrap': True, 'max_samples': 0.6105003335114606}. Best is trial 36 with value: 0.031865629539903455.
# [I 2026-04-14 16:05:40,709] Trial 40 finished with value: 0.03200595803504047 and parameters: {'n_estimators': 300, 'max_depth': 9, 'min_samples_split': 11, 'min_samples_leaf': 17, 'max_features': 'sqrt', 'bootstrap': True, 'max_samples': 0.6572868920563583}. Best is trial 36 with value: 0.031865629539903455.
# [I 2026-04-14 16:05:42,374] Trial 41 finished with value: 0.03190007207725342 and parameters: {'n_estimators': 800, 'max_depth': 3, 'min_samples_split': 12, 'min_samples_leaf': 18, 'max_features': 'log2', 'bootstrap': True, 'max_samples': 0.6027412617492707}. Best is trial 36 with value: 0.031865629539903455.
# [I 2026-04-14 16:05:43,496] Trial 42 finished with value: 0.031870989660500934 and parameters: {'n_estimators': 500, 'max_depth': 4, 'min_samples_split': 12, 'min_samples_leaf': 19, 'max_features': 'log2', 'bootstrap': True, 'max_samples': 0.6093646667456551}. Best is trial 36 with value: 0.031865629539903455.
# [I 2026-04-14 16:05:45,202] Trial 43 finished with value: 0.03190930434512011 and parameters: {'n_estimators': 800, 'max_depth': 5, 'min_samples_split': 10, 'min_samples_leaf': 19, 'max_features': 'log2', 'bootstrap': True, 'max_samples': 0.656113809563443}. Best is trial 36 with value: 0.031865629539903455.
# [I 2026-04-14 16:05:46,074] Trial 44 finished with value: 0.031861479302827095 and parameters: {'n_estimators': 400, 'max_depth': 7, 'min_samples_split': 12, 'min_samples_leaf': 19, 'max_features': 'log2', 'bootstrap': True, 'max_samples': 0.5298175339865905}. Best is trial 44 with value: 0.031861479302827095.
# [I 2026-04-14 16:05:46,941] Trial 45 finished with value: 0.03187035166506329 and parameters: {'n_estimators': 400, 'max_depth': 7, 'min_samples_split': 14, 'min_samples_leaf': 20, 'max_features': 'log2', 'bootstrap': True, 'max_samples': 0.5024856939108072}. Best is trial 44 with value: 0.031861479302827095.
# [I 2026-04-14 16:05:47,814] Trial 46 finished with value: 0.03184276703185318 and parameters: {'n_estimators': 400, 'max_depth': 8, 'min_samples_split': 14, 'min_samples_leaf': 20, 'max_features': 'log2', 'bootstrap': True, 'max_samples': 0.5352036051046962}. Best is trial 46 with value: 0.03184276703185318.
# [I 2026-04-14 16:05:48,399] Trial 47 finished with value: 0.035162277734786855 and parameters: {'n_estimators': 400, 'max_depth': 7, 'min_samples_split': 14, 'min_samples_leaf': 20, 'max_features': None, 'bootstrap': False}. Best is trial 46 with value: 0.03184276703185318.
# [I 2026-04-14 16:05:49,078] Trial 48 finished with value: 0.0318370882566531 and parameters: {'n_estimators': 300, 'max_depth': 8, 'min_samples_split': 12, 'min_samples_leaf': 19, 'max_features': 'log2', 'bootstrap': True, 'max_samples': 0.53033299511608}. Best is trial 48 with value: 0.0318370882566531.
# [I 2026-04-14 16:05:49,744] Trial 49 finished with value: 0.03189328161404733 and parameters: {'n_estimators': 300, 'max_depth': 12, 'min_samples_split': 16, 'min_samples_leaf': 20, 'max_features': 'sqrt', 'bootstrap': True, 'max_samples': 0.5300216978985525}. Best is trial 48 with value: 0.0318370882566531.
# [I 2026-04-14 16:05:50,246] Trial 50 finished with value: 0.03194811767078087 and parameters: {'n_estimators': 200, 'max_depth': 9, 'min_samples_split': 14, 'min_samples_leaf': 19, 'max_features': 'log2', 'bootstrap': True, 'max_samples': 0.5244560218674609}. Best is trial 48 with value: 0.0318370882566531.
# [I 2026-04-14 16:05:51,330] Trial 51 finished with value: 0.03186399879299091 and parameters: {'n_estimators': 500, 'max_depth': 8, 'min_samples_split': 12, 'min_samples_leaf': 19, 'max_features': 'log2', 'bootstrap': True, 'max_samples': 0.5009306814860695}. Best is trial 48 with value: 0.0318370882566531.
# [I 2026-04-14 16:05:52,419] Trial 52 finished with value: 0.03191543729680209 and parameters: {'n_estimators': 500, 'max_depth': 8, 'min_samples_split': 10, 'min_samples_leaf': 20, 'max_features': 'log2', 'bootstrap': True, 'max_samples': 0.5300141622525693}. Best is trial 48 with value: 0.0318370882566531.
# [I 2026-04-14 16:05:53,108] Trial 53 finished with value: 0.03190749221932119 and parameters: {'n_estimators': 300, 'max_depth': 10, 'min_samples_split': 12, 'min_samples_leaf': 17, 'max_features': 'log2', 'bootstrap': True, 'max_samples': 0.5022640975804669}. Best is trial 48 with value: 0.0318370882566531.
# [I 2026-04-14 16:05:53,986] Trial 54 finished with value: 0.031870000213388865 and parameters: {'n_estimators': 400, 'max_depth': 8, 'min_samples_split': 15, 'min_samples_leaf': 19, 'max_features': 'log2', 'bootstrap': True, 'max_samples': 0.5001505306894403}. Best is trial 48 with value: 0.0318370882566531.
# [I 2026-04-14 16:05:54,918] Trial 55 finished with value: 0.03272379185037277 and parameters: {'n_estimators': 400, 'max_depth': 11, 'min_samples_split': 11, 'min_samples_leaf': 4, 'max_features': 'log2', 'bootstrap': True, 'max_samples': 0.5437175661998851}. Best is trial 48 with value: 0.0318370882566531.
# [I 2026-04-14 16:05:55,532] Trial 56 finished with value: 0.032622260931131325 and parameters: {'n_estimators': 400, 'max_depth': 8, 'min_samples_split': 16, 'min_samples_leaf': 19, 'max_features': 'log2', 'bootstrap': False}. Best is trial 48 with value: 0.0318370882566531.
# [I 2026-04-14 16:05:56,026] Trial 57 finished with value: 0.03217713981326925 and parameters: {'n_estimators': 200, 'max_depth': 10, 'min_samples_split': 15, 'min_samples_leaf': 17, 'max_features': 'log2', 'bootstrap': True, 'max_samples': 0.9357480499849211}. Best is trial 48 with value: 0.0318370882566531.
# [I 2026-04-14 16:05:57,137] Trial 58 finished with value: 0.03191088363888633 and parameters: {'n_estimators': 500, 'max_depth': 13, 'min_samples_split': 13, 'min_samples_leaf': 19, 'max_features': 'log2', 'bootstrap': True, 'max_samples': 0.5293992535479208}. Best is trial 48 with value: 0.0318370882566531.
# [I 2026-04-14 16:05:57,828] Trial 59 finished with value: 0.032075880211345754 and parameters: {'n_estimators': 300, 'max_depth': 6, 'min_samples_split': 11, 'min_samples_leaf': 16, 'max_features': None, 'bootstrap': True, 'max_samples': 0.5245812899400198}. Best is trial 48 with value: 0.0318370882566531.
# [I 2026-04-14 16:05:58,937] Trial 60 finished with value: 0.031917762725558955 and parameters: {'n_estimators': 500, 'max_depth': 11, 'min_samples_split': 9, 'min_samples_leaf': 18, 'max_features': 'sqrt', 'bootstrap': True, 'max_samples': 0.5693002561144365}. Best is trial 48 with value: 0.0318370882566531.
# [I 2026-04-14 16:05:59,811] Trial 61 finished with value: 0.03187359493804515 and parameters: {'n_estimators': 400, 'max_depth': 7, 'min_samples_split': 14, 'min_samples_leaf': 20, 'max_features': 'log2', 'bootstrap': True, 'max_samples': 0.5041498419974199}. Best is trial 48 with value: 0.0318370882566531.
# [I 2026-04-14 16:06:00,683] Trial 62 finished with value: 0.031886337738230366 and parameters: {'n_estimators': 400, 'max_depth': 8, 'min_samples_split': 14, 'min_samples_leaf': 20, 'max_features': 'log2', 'bootstrap': True, 'max_samples': 0.501335810827902}. Best is trial 48 with value: 0.0318370882566531.
# [I 2026-04-14 16:06:01,171] Trial 63 finished with value: 0.03188044722671928 and parameters: {'n_estimators': 200, 'max_depth': 9, 'min_samples_split': 15, 'min_samples_leaf': 19, 'max_features': 'log2', 'bootstrap': True, 'max_samples': 0.5408540026632309}. Best is trial 48 with value: 0.0318370882566531.
# [I 2026-04-14 16:06:02,466] Trial 64 finished with value: 0.03188347059205239 and parameters: {'n_estimators': 600, 'max_depth': 5, 'min_samples_split': 13, 'min_samples_leaf': 18, 'max_features': 'log2', 'bootstrap': True, 'max_samples': 0.5174269024375983}. Best is trial 48 with value: 0.0318370882566531.
# [I 2026-04-14 16:06:03,142] Trial 65 finished with value: 0.03185798536587589 and parameters: {'n_estimators': 300, 'max_depth': 7, 'min_samples_split': 12, 'min_samples_leaf': 20, 'max_features': 'log2', 'bootstrap': True, 'max_samples': 0.561866865136525}. Best is trial 48 with value: 0.0318370882566531.
# [I 2026-04-14 16:06:03,882] Trial 66 finished with value: 0.03188210625314197 and parameters: {'n_estimators': 300, 'max_depth': 6, 'min_samples_split': 12, 'min_samples_leaf': 18, 'max_features': 'log2', 'bootstrap': True, 'max_samples': 0.5895583562034807}. Best is trial 48 with value: 0.0318370882566531.
# [I 2026-04-14 16:06:05,913] Trial 67 finished with value: 0.03254421989163423 and parameters: {'n_estimators': 1500, 'max_depth': 8, 'min_samples_split': 10, 'min_samples_leaf': 20, 'max_features': 'log2', 'bootstrap': False}. Best is trial 48 with value: 0.0318370882566531.
# [I 2026-04-14 16:06:06,586] Trial 68 finished with value: 0.031952382178214646 and parameters: {'n_estimators': 300, 'max_depth': 4, 'min_samples_split': 11, 'min_samples_leaf': 17, 'max_features': 'log2', 'bootstrap': True, 'max_samples': 0.5644400728216268}. Best is trial 48 with value: 0.0318370882566531.
# [I 2026-04-14 16:06:07,725] Trial 69 finished with value: 0.031912251057762055 and parameters: {'n_estimators': 500, 'max_depth': 7, 'min_samples_split': 12, 'min_samples_leaf': 19, 'max_features': 'log2', 'bootstrap': True, 'max_samples': 0.5610443082046453}. Best is trial 48 with value: 0.0318370882566531.
# [I 2026-04-14 16:06:08,058] Trial 70 finished with value: 0.03301059233120006 and parameters: {'n_estimators': 100, 'max_depth': 10, 'min_samples_split': 13, 'min_samples_leaf': 8, 'max_features': None, 'bootstrap': True, 'max_samples': 0.5397674768008464}. Best is trial 48 with value: 0.0318370882566531.
# [I 2026-04-14 16:06:08,933] Trial 71 finished with value: 0.0318475755939593 and parameters: {'n_estimators': 400, 'max_depth': 7, 'min_samples_split': 14, 'min_samples_leaf': 20, 'max_features': 'log2', 'bootstrap': True, 'max_samples': 0.5175874337292603}. Best is trial 48 with value: 0.0318370882566531.
# [I 2026-04-14 16:06:09,810] Trial 72 finished with value: 0.031867584787295275 and parameters: {'n_estimators': 400, 'max_depth': 27, 'min_samples_split': 15, 'min_samples_leaf': 19, 'max_features': 'log2', 'bootstrap': True, 'max_samples': 0.5193336494000813}. Best is trial 48 with value: 0.0318370882566531.
# [I 2026-04-14 16:06:10,921] Trial 73 finished with value: 0.031879057477960576 and parameters: {'n_estimators': 500, 'max_depth': 25, 'min_samples_split': 13, 'min_samples_leaf': 20, 'max_features': 'log2', 'bootstrap': True, 'max_samples': 0.5823799258709589}. Best is trial 48 with value: 0.0318370882566531.
# [I 2026-04-14 16:06:11,434] Trial 74 finished with value: 0.031884225649122064 and parameters: {'n_estimators': 200, 'max_depth': 29, 'min_samples_split': 12, 'min_samples_leaf': 18, 'max_features': 'log2', 'bootstrap': True, 'max_samples': 0.5204317313371164}. Best is trial 48 with value: 0.0318370882566531.
# Best trial: 48
# Best MSE: 0.0318370882566531
# Best hyperparameters:
# {'n_estimators': 300, 'max_depth': 8, 'min_samples_split': 12, 'min_samples_leaf': 19, 'max_features': 'log2', 'bootstrap': True, 'max_samples': 0.53033299511608}

# %% [markdown]
# $$\text{RMS} = \sqrt{\frac{1}{N}\sum_{i=1}^{N}(\Delta\mu_i - \Delta\mu_{\rm ML, predict})^2}$$

# %%
best_params = {'n_estimators': 900, 'max_depth': 14, 'min_samples_split': 16, 'min_samples_leaf': 4, 'max_features': None, 'bootstrap': True, 'max_samples': 0.801423245872187}

print(best_params)
best_params["n_jobs"] = -1
best_params["random_state"] = 42

rf = RandomForestRegressor(**best_params)
rf.fit(X, y)
y_pred = rf.predict(X)

# RMS of prediction residuals
rms = np.sqrt(np.mean((y.to_numpy() - y_pred) ** 2))

print("RMS:", rms)

plt.hist(y_pred)
# Out:
# {'n_estimators': 900, 'max_depth': 14, 'min_samples_split': 16, 'min_samples_leaf': 4, 'max_features': None, 'bootstrap': True, 'max_samples': 0.801423245872187}
# RMS: 0.13736949876902202
# (array([ 4., 32., 66., 90., 77., 88., 79., 50., 23., 12.]),
#  array([-0.2037025 , -0.16490899, -0.12611549, -0.08732198, -0.04852848,
#         -0.00973497,  0.02905853,  0.06785204,  0.10664555,  0.14543905,
#          0.18423256]),
#  <BarContainer object of 10 artists>)

# %%
# Define the following global parameters:

alpha = 0.161
beta  = 3.05

df["ZTF_mu_obs"] = -2.5 * np.log10(df["ZTF_x0"]) + alpha * df["ZTF_x1"] - beta * df["ZTF_c"]

# Define the following cosmology:
cosmo = FlatLambdaCDM(H0=70, Om0=0.3)

# Evaluate the cosmology at the ZTF reported redshift. We are using the ZTF redshift instead of DESI
# b/c we're propagating the ZTF uncertainty and we want to keep everything in the same data set. 

mu_th = cosmo.distmod(df["ZTF_redshift"]).value
corrected_residuals = df["ZTF_mu_obs"] - mu_th - (-29.759687) - y_pred

plt.hist(corrected_residuals) 
plt.xlabel(r"$\Delta\mu = -2.5\log x_0 + \alpha x_1 - \beta c - \mathscr{M} - \mu_{\rm th} - ML_{pred}$")

rms_corrected = np.sqrt(np.mean(corrected_residuals ** 2))
print("RMS of corrected residuals:", rms_corrected)

feature_importances = pd.Series(rf.feature_importances_, index=feature_cols).sort_values(ascending=False)
print(feature_importances)
# Out:
# RMS of corrected residuals: 0.13736949875161694
# DESI_FASTSPEC_g_minus_r    0.251181
# DESI_METADATA_Z            0.191125
# DESI_FASTSPEC_LOGMSTAR     0.150162
# DESI_FASTSPEC_DN4000       0.126905
# DESI_FASTSPEC_VDISP        0.098316
# DESI_FASTSPEC_AGE          0.091237
# DESI_FASTSPEC_SFR          0.091073
# dtype: float64

# %%
# Define the following global parameters:

alpha = 0.161
beta  = 3.05

df["ZTF_mu_obs"] = -2.5 * np.log10(df["ZTF_x0"]) + alpha * df["ZTF_x1"] - beta * df["ZTF_c"]

# Define the following cosmology:
cosmo = FlatLambdaCDM(H0=70, Om0=0.3)

# Evaluate the cosmology at the ZTF reported redshift. We are using the ZTF redshift instead of DESI
# b/c we're propagating the ZTF uncertainty and we want to keep everything in the same data set. 

mu_th = cosmo.distmod(df["ZTF_redshift"]).value
corrected_residuals = df["ZTF_mu_obs"] - mu_th - (-29.759687) #- y_pred

plt.hist(corrected_residuals) 
plt.xlabel(r"$\Delta\mu = -2.5\log x_0 + \alpha x_1 - \beta c - \mathscr{M} - \mu_{\rm th}$")

rms_corrected = np.sqrt(np.mean(corrected_residuals ** 2))
print("RMS of corrected residuals:", rms_corrected)

feature_importances = pd.Series(rf.feature_importances_, index=feature_cols).sort_values(ascending=False)
print(feature_importances)
# Out:
# RMS of corrected residuals: 0.18666577721809574
# DESI_FASTSPEC_g_minus_r    0.251181
# DESI_METADATA_Z            0.191125
# DESI_FASTSPEC_LOGMSTAR     0.150162
# DESI_FASTSPEC_DN4000       0.126905
# DESI_FASTSPEC_VDISP        0.098316
# DESI_FASTSPEC_AGE          0.091237
# DESI_FASTSPEC_SFR          0.091073
# dtype: float64

# %% [markdown]
# ## Why predictions Seem Like they are Capped
#
# The predicted residuals span a much narrower range than the true residuals.
# This is expected behavior when the features carry little predictive signal.
#
# Each Random Forest prediction is the average of `n_predictors` individual tree
# predictions. When the features (host galaxy properties) do not strongly
# determine the target (Hubble residuals), each tree essentially guesses
# near the sample mean. Averaging 1,000 near-zero guesses produces
# predictions tightly clustered around zero.
#
# This is consistent with a null result: host galaxy properties do not
# significantly predict Hubble residuals beyond the Tripp correction.
#
# Input from Dr. Armin Rest this shows evidence that our assumptions about
# the fact that host galaxies give some form of nonlinear non parametric relations/corrections
# to the Hubble residuals.

# %%
plt.figure(figsize=(6, 6))
plt.scatter(y, y_pred, alpha=0.7)
plt.xlabel(r"$\Delta\mu = -2.5\log x_0 + \alpha x_1 - \beta c - \mathscr{M} - \mu_{\rm th}$")
plt.ylabel(r"$\Delta\mu_{\mathrm{ML}_{\mathrm{predict}}}$")
plt.axline((0, 0), slope=1, linestyle="--")

plt.xlim(-1, 1)
plt.ylim(-1, 1)

plt.tight_layout()
plt.show()
